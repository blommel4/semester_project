# %%
import pandas as pd
import warnings

warnings.filterwarnings(action='once')

year = input("Year:")
year = str(year)
filestring = "KenPom"+year+"_raw.csv"
kenpom_df = pd.read_csv(filestring)

# drop teams not in tournament
droplist = []
    
for i in range(len(kenpom_df['Team'])):
    if not kenpom_df['Team'][i][-1].isdigit():
        kenpom_df = kenpom_df.drop([i])

kenpom_df = kenpom_df.reset_index(drop=True)
kenpom_df["Seed"] = 0

# Remove seed from Team Name and add to Seed column
for i in range(len(kenpom_df['Team'])):
    team = kenpom_df['Team'][i]
    if team[-1].isdigit() and team[-2].isdigit():
        seed = int(team[-2:])
        kenpom_df['Team'][i] = team[:-2]
    elif team[-1].isdigit():
        seed = int(team[-1])
        kenpom_df['Team'][i] = team[:-1]
    else:
        continue
    kenpom_df['Seed'][i] = seed

kenpom_df['W'] = 0
kenpom_df['L'] = 0
kenpom_df['Win%'] = 1.0

for i in range(len(kenpom_df['Team'])):
    kenpom_df['W'][i] = int(kenpom_df['W-L'][i][:2])
    if not kenpom_df['W-L'][i][-2].isdigit(): # >10 losses
        kenpom_df['L'][i] = int(kenpom_df['W-L'][i][-1])
    else:
        kenpom_df['L'][i] = int(kenpom_df['W-L'][i][-2:])
    kenpom_df['Win%'][i] = kenpom_df['W'][i]/(kenpom_df['W'][i]+kenpom_df['L'][i])

kenpom_df = kenpom_df.drop("W-L",axis=1)

print(kenpom_df.head(70))

choice = input("Look good (y/n)?")

if choice == "y":
    filename = "KenPom"+year+".csv"
    kenpom_df.to_csv(filename)
    print(filename, "written\n")
else:
    print("File not written\n")
# Out:
# Year:2002
# /Users/addisonwood/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                     Team  Conf  AdjEM   AdjO   AdjD  AdjT   Luck  SOSAdjEM  \
# 0                  Duke    ACC  34.19  121.0   86.8  74.5 -0.027      9.87
# 1            Cincinnati   CUSA  30.19  118.1   87.9  67.4  0.002      6.58
# 2              Maryland    ACC  29.25  119.2   89.9  73.7  0.025      9.88
# 3                Kansas    B12  28.99  118.7   89.7  77.3  0.022     10.67
# 4              Oklahoma    B12  26.04  114.9   88.9  66.5  0.043      8.77
# 5               Indiana    B10  24.80  114.0   89.2  65.6 -0.049     14.12
# 6               Florida    SEC  24.72  115.1   90.4  69.6 -0.073      9.11
# 7              Illinois    B10  23.21  115.7   92.5  68.5  0.016     10.60
# 8                Oregon    P10  22.97  119.2   96.3  71.1 -0.041      8.15
# 9              Kentucky    SEC  22.21  113.4   91.2  68.0 -0.029     12.97
# 10            Marquette   CUSA  21.47  113.4   91.9  64.6  0.006      5.41
# 11                  USC    P10  20.67  112.8   92.1  70.1 -0.051      9.31
# 12              Arizona    P10  20.54  119.3   98.8  71.1  0.079     14.22
# 53              Hampton   MEAC   3.99  109.9  105.9  69.1  0.013     -8.67
# 54     Illinois Chicago   Horz   3.85  108.9  105.0  67.5  0.040      1.84
# 55             Davidson     SC   3.70  101.5   97.8  65.1  0.142      1.79
# 56           Murray St.    OVC   1.35  106.8  105.5  69.2  0.017     -1.74
# 57  Central Connecticut    NEC   0.93  100.6   99.7  64.0  0.137    -11.95
# 58           Holy Cross    Pat  -0.24   98.1   98.4  62.2 -0.048     -6.40
# 59                Siena   MAAC  -1.21  100.8  102.0  66.5 -0.070     -4.14
# 60     Florida Atlantic   ASun  -2.50   99.6  102.1  70.2  0.060     -4.94
# 61    Boston University     AE  -2.74  101.3  104.0  64.5  0.102     -9.18
# 62              Montana   BSky  -4.51  102.4  106.9  68.5  0.053     -1.95
# 63             Winthrop   BSth  -5.31   97.3  102.6  65.9  0.038    -10.73
# 64           Alcorn St.   SWAC  -8.71  100.1  108.8  73.0  0.097    -14.53
#
#     NCSOSAdjEM  Seed   W   L      Win%
# 0         6.66     1  31   4  0.885714
# 1         3.48     1  31   4  0.885714
# 2         1.62     1  32   4  0.888889
# 3         8.32     1  33   4  0.891892
# 4        -0.44     2  31   5  0.861111
# 5        13.54     5  25  12  0.675676
# 6        -0.56     5  22   9  0.709677
# 7         6.79     4  26   9  0.742857
# 8        -3.30     2  26   9  0.742857
# 9         6.75     4  22  10  0.687500
# 10       -2.87     5  26   7  0.787879
# 11        1.90     4  22  10  0.687500
# 12       17.56     3  24  10  0.705882
# 13        2.99    10  29   6  0.828571
# 14        2.10     8  20  10  0.666667
# 15      -12.07     3  29   6  0.828571
# 16       -1.26     4  24   8  0.750000
# 17        1.73     2  27   7  0.794118
# 18       -1.55     8  21  11  0.656250
# 19       -5.56     7  23  11  0.676471
# 20       -1.56     2  27   8  0.771429
# 21        5.37     7  26   6  0.812500
# 22        4.04     6  28   4  0.875000
# 23        3.30     3  22   9  0.709677
# 24       -0.96     3  27   8  0.771429
# 25        5.30     6  22  12  0.647059
# 26       -0.39    12  24  12  0.666667
# 27        5.85     7  21  13  0.617647
# 28       -0.13     6  23   9  0.718750
# 29        1.50    10  19  12  0.612903
# ..         ...   ...  ..  ..       ...
# 35        6.49     9  18  12  0.600000
# 36       -1.44    12  26   7  0.787879
# 37        0.29     9  26   4  0.866667
# 38        1.57    12  19   9  0.678571
# 39        2.06    13  24   8  0.750000
# 40        3.16    11  28   8  0.777778
# 41        8.49     8  18  13  0.580645
# 42       -9.70    10  26   6  0.812500
# 43        0.98    11  25   7  0.781250
# 44        0.93    12  23   9  0.718750
# 45       11.94    10  21   9  0.700000
# 46        4.57    13  23  10  0.696970
# 47       -5.47    11  22   9  0.709677
# 48       -2.78    11  20  12  0.625000
# 49        0.67    13  21  12  0.636364
# 50       -0.79     9  20  12  0.625000
# 51        3.37    14  19  11  0.633333
# 52       12.81    14  20   9  0.689655
# 53        0.87    15  25   7  0.781250
# 54        0.67    15  18  14  0.562500
# 55        9.43    13  18  10  0.642857
# 56        3.98    14  17  13  0.566667
# 57       -4.98    14  27   5  0.843750
# 58       -3.38    16  18  15  0.545455
# 59       -0.42    16  17  19  0.472222
# 60       -4.52    15  18  12  0.600000
# 61        0.25    16  22  10  0.687500
# 62        0.44    15  14  15  0.482759
# 63       -0.98    16  17  12  0.586207
# 64        2.60    16  20  10  0.666667
#
# [65 rows x 13 columns]
# Look good (y/n)?y
# KenPom2002.csv written

# %%
import pandas as pd
year = str(2006)

filestring = year+"_tourney_teams.csv"
teams_df = pd.read_csv(filestring, header=None)

teamlist = []
for team in teams_df[0]:
    teamlist.append(team)
    
print(teamlist)
# Out:
# ['Air Force', 'Alabama', 'Albany (N.Y.)', 'Arizona', 'Arkansas', 'Belmont', 'Boston College', 'Bradley', 'Bucknell', 'California', 'Connecticut', 'Davidson', 'Duke', 'Florida', 'George Mason', 'George Washington', 'Georgetown', 'Gonzaga', 'Hampton', 'Illinois', 'Indiana', 'Iona', 'Iowa', 'Kansas', 'Kent St.', 'Kentucky', 'LSU', 'Marquette', 'Memphis', 'Michigan St.', 'Monmouth', 'Montana', 'Murray St.', 'Nevada', 'North Carolina', 'North Carolina St.', 'Northwestern St.', 'Ohio St.', 'Oklahoma', 'Oral Roberts', 'Pacific', 'Penn', 'Pittsburgh', 'San Diego St.', 'Seton Hall', 'South Ala.', 'Southern Ill.', 'Southern U.', 'Syracuse', 'Tennessee', 'Texas', 'Texas A&M', 'UAB', 'UCLA', 'UNC Wilmington', 'UNI', 'Utah St.', 'Villanova', 'Washington', 'West Virginia', 'Wichita St.', 'Winthrop', 'Wis.-Milwaukee', 'Wisconsin', 'Xavier']

# %%
import pandas as pd
import warnings

warnings.filterwarnings(action='once')


kenpom_df = pd.read_csv("KenPom2006_raw.csv")

# Remove seed from Team Name
for i in range(len(kenpom_df['Team'])):
    team = kenpom_df['Team'][i]
    if team[-1].isdigit() and team[-2].isdigit():
        seed = int(team[-2:])
        kenpom_df['Team'][i] = team[:-2]
    elif team[-1].isdigit():
        seed = int(team[-1])
        kenpom_df['Team'][i] = team[:-1]
    else:
        continue
    #kenpom_df['Seed'][i] = seed

len(kenpom_df['Team'])
# Out:
# /Users/addisonwood/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-b3e18bc5b78e> in <module>
#      20     #kenpom_df['Seed'][i] = seed
#      21
# ---> 22 kenpom_df.size()
#
# TypeError: 'numpy.int64' object is not callable
