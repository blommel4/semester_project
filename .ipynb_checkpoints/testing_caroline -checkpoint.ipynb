# %%
import xgboost as xgb
import pandas as pd 
import matplotlib.pyplot as plt

# %%
full_results = pd.read_csv('full_results.csv')
full_results
full_stats = pd.read_csv('FullKenPom_pt.csv')
#full_stats
# Out:
# ['Unnamed: 0', 'Year', 'Round', 'Region Number', 'Region Name', 'SeedA', 'ScoreA', 'TeamA', 'TeamB', 'ScoreB', 'SeedB']

# %%
#mask = (data['value2'] == 'A') & (data['value'] > 4)
test_mask = (full_results['Year'] == 2016) | (full_results['Year'] == 2017) | (full_results['Year'] == 2018)
data_test = full_results[test_mask]

train_mask = (full_results['Year'] != 2016) & (full_results['Year'] != 2017) & (full_results['Year'] != 2018)
data_train = full_results[train_mask]

label = list(full_results.columns.values)

data_train
# Out:
#      Unnamed: 0  Year  Round  Region Number   Region Name  SeedA  ScoreA  \
# 0             0  2002      0              0    First Four     16      77
# 1             1  2002      1              1         South      1      84
# 2             2  2002      1              1         South      2      86
# 3             3  2002      1              1         South      3      71
# 4             4  2002      1              1         South      4      89
# 5             5  2002      1              1         South      5      75
# 6             6  2002      1              1         South      6      82
# 7             7  2002      1              1         South      7      61
# 8             8  2002      1              1         South      8      82
# 9             9  2002      1              2          West      1      90
# 10           10  2002      1              2          West      2      71
# 11           11  2002      1              2          West      3      86
# 12           12  2002      1              2          West      4      69
# 13           13  2002      1              2          West      5      80
# 14           14  2002      1              2          West      6      66
# 15           15  2002      1              2          West      7      70
# 16           16  2002      1              2          West      8      80
# 17           17  2002      1              3          East      1      85
# 18           18  2002      1              3          East      2      78
# 19           19  2002      1              3          East      3      85
# 20           20  2002      1              3          East      4      83
# 21           21  2002      1              3          East      5      69
# 22           22  2002      1              3          East      6      68
# 23           23  2002      1              3          East      7      69
# 24           24  2002      1              3          East      8      80
# 25           25  2002      1              4       Midwest      1      70
# 26           26  2002      1              4       Midwest      2      81
# 27           27  2002      1              4       Midwest      3      70
# 28           28  2002      1              4       Midwest      4      93
# 29           29  2002      1              4       Midwest      5      82
# ..          ...   ...    ...            ...           ...    ...     ...
# 881         881  2015      2              1       Midwest      2      65
# 882         882  2015      2              1       Midwest      3      67
# 883         883  2015      2              1       Midwest      4      59
# 884         884  2015      2              2          West      1      72
# 885         885  2015      2              2          West      2      73
# 886         886  2015      2              2          West      6      75
# 887         887  2015      2              2          West      4      87
# 888         888  2015      2              3          East      1      68
# 889         889  2015      2              3          East      2      54
# 890         890  2015      2              3          East      3      72
# 891         891  2015      2              3          East      4      66
# 892         892  2015      2              4         South      1      68
# 893         893  2015      2              4         South      2      87
# 894         894  2015      2              4         South     11      92
# 895         895  2015      2              4         South      4      64
# 896         896  2015      3              1       Midwest      1      78
# 897         897  2015      3              1       Midwest      3      81
# 898         898  2015      3              2          West      1      79
# 899         899  2015      3              2          West      2      68
# 900         900  2015      3              3          East      4      75
# 901         901  2015      3              3          East      3      58
# 902         902  2015      3              4         South      1      63
# 903         903  2015      3              4         South      2      74
# 904         904  2015      4              1       Midwest      1      68
# 905         905  2015      4              2          West      1      85
# 906         906  2015      4              3          East      4      70
# 907         907  2015      4              4         South      1      66
# 908         908  2015      5              1    Final Four      1      71
# 909         909  2015      5              2    Final Four      1      81
# 910         910  2015      6              1  Championship      1      68
#
#               TeamA                   TeamB  ScoreB  SeedB
# 0         Alcorn St                   Siena      81     16
# 1              Duke                Winthrop      37     16
# 2           Alabama        Florida Atlantic      78     15
# 3        Pittsburgh  Central Connecticut St      54     14
# 4               USC          UNC Wilmington      93     13
# 5           Indiana                    Utah      56     12
# 6        California            Pennsylvania      75     11
# 7       Oklahoma St                 Kent St      69     10
# 8        Notre Dame               Charlotte      63      9
# 9        Cincinnati       Boston University      52     16
# 10         Oklahoma        Illinois Chicago      63     15
# 11          Arizona           Santa Barbara      81     14
# 12          Ohio St                Davidson      64     13
# 13            Miami                Missouri      93     12
# 14          Gonzaga                 Wyoming      73     11
# 15           Xavier                  Hawaii      58     10
# 16             UCLA                Ole Miss      58      9
# 17         Maryland                   Siena      70     16
# 18      Connecticut                 Hampton      67     15
# 19          Georgia               Murray St      68     14
# 20         Kentucky              Valparaiso      68     13
# 21        Marquette                   Tulsa      71     12
# 22       Texas Tech       Southern Illinois      76     11
# 23         NC State             Michigan St      58     10
# 24        Wisconsin                St Johns      70      9
# 25           Kansas              Holy Cross      59     16
# 26           Oregon                 Montana      62     15
# 27   Mississippi St              McNeese St      58     14
# 28         Illinois            San Diego St      64     13
# 29          Florida               Creighton      83     12
# ..              ...                     ...     ...    ...
# 881          Kansas              Wichita St      78      7
# 882      Notre Dame                  Butler      64      6
# 883        Maryland           West Virginia      69      5
# 884       Wisconsin                  Oregon      65      8
# 885         Arizona                 Ohio St      58     10
# 886          Xavier              Georgia St      67     14
# 887  North Carolina                Arkansas      78      5
# 888       Villanova                NC State      71      8
# 889        Virginia             Michigan St      60      7
# 890        Oklahoma                  Dayton      66     11
# 891      Louisville           Northern Iowa      53      5
# 892            Duke            San Diego St      49      8
# 893         Gonzaga                    Iowa      68      7
# 894            UCLA                     UAB      75     14
# 895      Georgetown                    Utah      75      5
# 896        Kentucky           West Virginia      39      5
# 897      Notre Dame              Wichita St      70      7
# 898       Wisconsin          North Carolina      72      4
# 899         Arizona                  Xavier      60      6
# 900      Louisville                NC State      65      8
# 901        Oklahoma             Michigan St      62      7
# 902            Duke                    Utah      57      5
# 903         Gonzaga                    UCLA      62     11
# 904        Kentucky              Notre Dame      66      3
# 905       Wisconsin                 Arizona      78      2
# 906      Louisville             Michigan St      76      7
# 907            Duke                 Gonzaga      52      2
# 908       Wisconsin                Kentucky      64      1
# 909            Duke             Michigan St      61      7
# 910            Duke               Wisconsin      63      1
#
# [911 rows x 11 columns]

# %%
train = xgb.DMatrix(data_train, label=label)
test = xgb.DMatrix(data_test, label = label)
