# %%
import xgboost as xgb
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import graphviz
from sklearn import preprocessing

# %%
full_results = pd.read_csv('full_results.csv')

full_stats = pd.read_csv('FullKenPom_pt.csv')

#full_results
print(full_stats.columns)
# Out:
# Index(['Unnamed: 0', 'Season', 'TeamName', 'Tempo', 'AdjTempo', 'OE', 'AdjOE',
#        'DE', 'AdjDE', 'AdjEM', 'seed', 'ConfTournament', 'SOSAdjEM',
#        'NCSOSAdjEM', 'O_eFG_Pct', 'D_eFG_Pct', 'O-D_eFG_Pct', 'O_TO_Pct',
#        'D_TO_Pct', 'D-O_TO_Pct', 'O_OR_Pct', 'D_OR_Pct', 'O-D_OR_Pct',
#        'O_FT_Rate', 'D_FT_Rate', 'O-D_FT_Rate', 'LastTenRecord'],
#       dtype='object')

# %%
full_stats

stats_vec = ["AdjTempo", 
            "AdjOE",
            "AdjDE",
            "AdjEM",
            "seed",
            "ConfTournament",
            "SOSAdjEM",
            "NCSOSAdjEM",
            "O-D_eFG_Pct",
            "D-O_TO_Pct",
            "O-D_OR_Pct",
            "O-D_FT_Rate",
            "LastTenRecord"]

print(len(stats_vec))

#target_stats = pd.DataFrame(columns = stats_vec)

#for i in range(len(stats_vec)):
#    target_stats[stats_vec[i]] = full_stats[stats_vec[i]]

#target_stats.columns

#target_stats.head()
# Out:
# 13

# %%
###mask test and train data###
res_test_mask = (full_results['Year'] == 2016) | (full_results['Year'] == 2017) | (full_results['Year'] == 2018)
stats_test_mask = (full_stats['Season'] == 2016) | (full_stats['Season'] == 2017) | (full_stats['Season'] == 2018)
res_train_mask = (full_results['Year'] < 2016)
stats_train_mask = (full_stats['Season'] < 2016)

res_data_test = full_results[res_test_mask]
stats_data_test = full_stats[stats_test_mask]
res_data_train = full_results[res_train_mask]
stats_data_train = full_stats[stats_train_mask]

#reindex all of them
res_data_test = res_data_test.reset_index()
stats_data_test = stats_data_test.reset_index()
res_data_train = res_data_train.reset_index()
stats_data_train = stats_data_train.reset_index()

for i in range(len(res_data_test)):
    if res_data_test['Region Name'][i] == "First Four":
        res_data_test = res_data_test.drop(i)
for i in range(len(res_data_train)):
    if res_data_train['Region Name'][i] == "First Four":
        res_data_train = res_data_train.drop(i)
        
#reindex all of them
res_data_test = res_data_test.reset_index()
stats_data_test = stats_data_test.reset_index()
res_data_train = res_data_train.reset_index()
stats_data_train = stats_data_train.reset_index()

res_data_train.head()
# Out:
#    level_0  index  Unnamed: 0  Year  Round  Region Number Region Name  SeedA  \
# 0        1      1           1  2002      1              1       South      1
# 1        2      2           2  2002      1              1       South      2
# 2        3      3           3  2002      1              1       South      3
# 3        4      4           4  2002      1              1       South      4
# 4        5      5           5  2002      1              1       South      5
#
#    ScoreA       TeamA                   TeamB  ScoreB  SeedB
# 0      84        Duke                Winthrop      37     16
# 1      86     Alabama        Florida Atlantic      78     15
# 2      71  Pittsburgh  Central Connecticut St      54     14
# 3      89         USC          UNC Wilmington      93     13
# 4      75     Indiana                    Utah      56     12

# %%
#training_data = np.zeros((len(res_data_train), len(stats_vec)))
#print(np.shape(training_data))

##Pandas data fram method, abandoned for numpy method 

#for i in range(len(res_data_train)): 
#    Season = res_data_train['Year'][i]
#    TeamA = res_data_train['TeamA'][i]
#   TeamB = res_data_train['TeamB'][i]
    
#    A_mask = (stats_data_train['Season'] == Season) & (stats_data_train['TeamName'] == TeamA)                        
#    A = stats_data_train[A_mask]
    #print(A)
    
#    B_mask = (stats_data_train['Season'] == Season) & (stats_data_train['TeamName'] == TeamB)
#    B = stats_data_train[B_mask]

    #A_value = A[stats_vec[2]].iloc[0]
    #A_value = A_series.iloc[0]
    #print(A_value)
    #print(B)



#    for j in range(2,len(stats_vec)): 
#        training_data[i,j-2] = A[stats_vec[j]].iloc[0] - B[stats_vec[j]].iloc[0]
    #print(i)
    #print(training_data)

# %%
##Ended up not using this block of code for creating data vectors either 

###mask test data###
#test_mask = (full_results['Year'] == 2016) | (full_results['Year'] == 2017) | (full_results['Year'] == 2018)
#data_test = full_results[test_mask]

###getting rid of non-float columns (Region Name, TeamA, TeamB)###
#data_clean_mask = (full_results.columns.values != 'Region Name') & (full_results.columns.values != 'TeamA') & (full_results.columns.values != 'TeamB')

#data_test_clean = data_test.columns[data_clean_mask]
#test_columns_list = list(data_test_clean)

#new_data_test = pd.DataFrame(columns = test_columns_list)

#for i in range(len(test_columns_list)):
#    new_data_test[test_columns_list[i]] = data_test[test_columns_list[i]]
    

###mask train data###
#train_mask = (full_results['Year'] != 2016) & (full_results['Year'] != 2017) & (full_results['Year'] != 2018)
#data_train = full_results[train_mask]

###getting rid of non-float columns (Region Name, TeamA, TeamB)###
#data_clean_mask = (full_results.columns.values != 'Region Name') & (full_results.columns.values != 'TeamA') & (full_results.columns.values != 'TeamB')

#data_train_clean = data_train.columns[data_clean_mask]
#train_columns_list = list(data_train_clean)

#new_data_train = pd.DataFrame(columns = train_columns_list)

#for i in range(len(train_columns_list)):
#    new_data_train[train_columns_list[i]] = data_train[train_columns_list[i]]


#new_data_test

# %%
# Move training data into 2 numpy arrays - data and labels (results)
N = len(res_data_train)

training_data = np.zeros((N,13))
training_labels = np.zeros((N,1))

for i in range(len(res_data_train)):
    year = res_data_train['Year'][i]
    teamA = res_data_train['TeamA'][i]
    teamB = res_data_train['TeamB'][i]
    score_diff = res_data_train['ScoreA'][i] - res_data_train['ScoreB'][i]
    for k in range(len(stats_data_train)):
        if ((stats_data_train['Season'][k] == year) and (stats_data_train['TeamName'][k] == teamA)):
            indexA = k
            break
            
    for k in range(len(stats_data_train)):
        if ((stats_data_train['Season'][k] == year) and (stats_data_train['TeamName'][k] == teamB)):
            indexB = k
            break
    for s in range(len(stats_vec)):
        stat = stats_vec[s]
        training_data[i][s] = stats_data_train[stat][indexA] - stats_data_train[stat][indexB]
    
    if (score_diff > 0):
        training_labels[i][0] = 1
    else:
        training_labels[i][0] = 0

# %%
print(training_data.shape)
print(training_labels.shape)
print('\n')
print(testing_data.shape)
print(testing_labels.shape)
# Out:
# (882, 13)
# (882, 1)
#
#
# (189, 13)
# (189, 1)

# %%
#Time to normalize the data
#switch axis to 0 to normailze columns instead of rows 

training_data = preprocessing.normalize(training_data, axis=0, norm='max')
testing_data = preprocessing.normalize(testing_data, axis=0, norm='max')

# %%
dtrain = xgb.DMatrix(training_data, label=training_labels,
                     feature_names=stats_vec)
dtest = xgb.DMatrix(testing_data, label=testing_labels,
                    feature_names=stats_vec)

# %%
param = {}
evallist = [(dtest, 'eval'), (dtrain, 'train')]

num_round = 500 #looks like it levels off at around 200
bst = xgb.train(param, dtrain, num_round, evallist)
# Out:
# [0]	eval-rmse:0.377778	train-rmse:0.427859
# [1]	eval-rmse:0.293829	train-rmse:0.381052
# [2]	eval-rmse:0.316696	train-rmse:0.352045
# [3]	eval-rmse:0.297198	train-rmse:0.319463
# [4]	eval-rmse:0.165227	train-rmse:0.291606
# [5]	eval-rmse:0.140037	train-rmse:0.277335
# [6]	eval-rmse:0.044937	train-rmse:0.2616
# [7]	eval-rmse:0.043803	train-rmse:0.25638
# [8]	eval-rmse:0.039724	train-rmse:0.249788
# [9]	eval-rmse:0.044542	train-rmse:0.24255
# [10]	eval-rmse:0.044272	train-rmse:0.237158
# [11]	eval-rmse:0.044268	train-rmse:0.230813
# [12]	eval-rmse:0.092627	train-rmse:0.215077
# [13]	eval-rmse:0.09701	train-rmse:0.206722
# [14]	eval-rmse:0.139413	train-rmse:0.196245
# [15]	eval-rmse:0.129059	train-rmse:0.185703
# [16]	eval-rmse:0.128325	train-rmse:0.177377
# [17]	eval-rmse:0.125931	train-rmse:0.174198
# [18]	eval-rmse:0.127383	train-rmse:0.171837
# [19]	eval-rmse:0.128322	train-rmse:0.166534
# [20]	eval-rmse:0.1314	train-rmse:0.160681
# [21]	eval-rmse:0.130632	train-rmse:0.154482
# [22]	eval-rmse:0.141674	train-rmse:0.143446
# [23]	eval-rmse:0.162498	train-rmse:0.135669
# [24]	eval-rmse:0.202324	train-rmse:0.130318
# [25]	eval-rmse:0.158315	train-rmse:0.124252
# [26]	eval-rmse:0.15318	train-rmse:0.123205
# [27]	eval-rmse:0.139384	train-rmse:0.114942
# [28]	eval-rmse:0.139329	train-rmse:0.109278
# [29]	eval-rmse:0.150428	train-rmse:0.102313
# [30]	eval-rmse:0.12403	train-rmse:0.09826
# [31]	eval-rmse:0.124032	train-rmse:0.094692
# [32]	eval-rmse:0.123927	train-rmse:0.090333
# [33]	eval-rmse:0.126755	train-rmse:0.087112
# [34]	eval-rmse:0.129196	train-rmse:0.085016
# [35]	eval-rmse:0.12903	train-rmse:0.084537
# [36]	eval-rmse:0.129635	train-rmse:0.082844
# [37]	eval-rmse:0.109358	train-rmse:0.081131
# [38]	eval-rmse:0.108326	train-rmse:0.079818
# [39]	eval-rmse:0.10895	train-rmse:0.07816
# [40]	eval-rmse:0.109934	train-rmse:0.076326
# [41]	eval-rmse:0.14406	train-rmse:0.072171
# [42]	eval-rmse:0.144087	train-rmse:0.070434
# [43]	eval-rmse:0.145834	train-rmse:0.068976
# [44]	eval-rmse:0.145185	train-rmse:0.066921
# [45]	eval-rmse:0.144521	train-rmse:0.066025
# [46]	eval-rmse:0.140937	train-rmse:0.063746
# [47]	eval-rmse:0.14063	train-rmse:0.059523
# [48]	eval-rmse:0.140119	train-rmse:0.057024
# [49]	eval-rmse:0.162956	train-rmse:0.055308
# [50]	eval-rmse:0.160878	train-rmse:0.053838
# [51]	eval-rmse:0.16148	train-rmse:0.05266
# [52]	eval-rmse:0.161279	train-rmse:0.052048
# [53]	eval-rmse:0.160852	train-rmse:0.049974
# [54]	eval-rmse:0.160746	train-rmse:0.049156
# [55]	eval-rmse:0.159575	train-rmse:0.048226
# [56]	eval-rmse:0.161354	train-rmse:0.04557
# [57]	eval-rmse:0.161574	train-rmse:0.043956
# [58]	eval-rmse:0.161252	train-rmse:0.041836
# [59]	eval-rmse:0.159783	train-rmse:0.03961
# [60]	eval-rmse:0.160003	train-rmse:0.038095
# [61]	eval-rmse:0.159266	train-rmse:0.037011
# [62]	eval-rmse:0.159136	train-rmse:0.036613
# [63]	eval-rmse:0.159567	train-rmse:0.035007
# [64]	eval-rmse:0.158769	train-rmse:0.033672
# [65]	eval-rmse:0.155991	train-rmse:0.031991
# [66]	eval-rmse:0.15635	train-rmse:0.030603
# [67]	eval-rmse:0.156925	train-rmse:0.029496
# [68]	eval-rmse:0.163441	train-rmse:0.028245
# [69]	eval-rmse:0.160009	train-rmse:0.027102
# [70]	eval-rmse:0.156904	train-rmse:0.025286
# [71]	eval-rmse:0.157134	train-rmse:0.024754
# [72]	eval-rmse:0.15713	train-rmse:0.024116
# [73]	eval-rmse:0.156859	train-rmse:0.023706
# [74]	eval-rmse:0.160295	train-rmse:0.022627
# [75]	eval-rmse:0.158443	train-rmse:0.021666
# [76]	eval-rmse:0.158538	train-rmse:0.020803
# [77]	eval-rmse:0.157749	train-rmse:0.020076
# [78]	eval-rmse:0.157756	train-rmse:0.019825
# [79]	eval-rmse:0.158055	train-rmse:0.01884
# [80]	eval-rmse:0.158151	train-rmse:0.018621
# [81]	eval-rmse:0.158171	train-rmse:0.018094
# [82]	eval-rmse:0.158106	train-rmse:0.017492
# [83]	eval-rmse:0.157948	train-rmse:0.016418
# [84]	eval-rmse:0.1579	train-rmse:0.015973
# [85]	eval-rmse:0.157629	train-rmse:0.015285
# [86]	eval-rmse:0.15715	train-rmse:0.014681
# [87]	eval-rmse:0.156823	train-rmse:0.014314
# [88]	eval-rmse:0.156688	train-rmse:0.013848
# [89]	eval-rmse:0.154875	train-rmse:0.013255
# [90]	eval-rmse:0.155328	train-rmse:0.013115
# [91]	eval-rmse:0.155097	train-rmse:0.012932
# [92]	eval-rmse:0.151922	train-rmse:0.012514
# [93]	eval-rmse:0.151958	train-rmse:0.012202
# [94]	eval-rmse:0.151257	train-rmse:0.011614
# [95]	eval-rmse:0.150126	train-rmse:0.011112
# [96]	eval-rmse:0.15016	train-rmse:0.010804
# [97]	eval-rmse:0.150039	train-rmse:0.010551
# [98]	eval-rmse:0.149962	train-rmse:0.010312
# [99]	eval-rmse:0.145766	train-rmse:0.009998
# [100]	eval-rmse:0.1463	train-rmse:0.009454
# [101]	eval-rmse:0.146333	train-rmse:0.009216
# [102]	eval-rmse:0.146567	train-rmse:0.009082
# [103]	eval-rmse:0.146456	train-rmse:0.008819
# [104]	eval-rmse:0.146394	train-rmse:0.008478
# [105]	eval-rmse:0.146892	train-rmse:0.007999
# [106]	eval-rmse:0.146704	train-rmse:0.007833
# [107]	eval-rmse:0.145437	train-rmse:0.007634
# [108]	eval-rmse:0.145497	train-rmse:0.007347
# [109]	eval-rmse:0.145251	train-rmse:0.007133
# [110]	eval-rmse:0.145148	train-rmse:0.007008
# [111]	eval-rmse:0.14516	train-rmse:0.006822
# [112]	eval-rmse:0.144568	train-rmse:0.006591
# [113]	eval-rmse:0.144515	train-rmse:0.006472
# [114]	eval-rmse:0.144675	train-rmse:0.006205
# [115]	eval-rmse:0.144697	train-rmse:0.006066
# [116]	eval-rmse:0.144665	train-rmse:0.005963
# [117]	eval-rmse:0.14471	train-rmse:0.005884
# [118]	eval-rmse:0.144705	train-rmse:0.005775
# [119]	eval-rmse:0.144615	train-rmse:0.005516
# [120]	eval-rmse:0.14476	train-rmse:0.005356
# [121]	eval-rmse:0.144758	train-rmse:0.005173
# [122]	eval-rmse:0.144694	train-rmse:0.005006
# [123]	eval-rmse:0.144727	train-rmse:0.004824
# [124]	eval-rmse:0.144738	train-rmse:0.004756
# [125]	eval-rmse:0.144657	train-rmse:0.004572
# [126]	eval-rmse:0.144236	train-rmse:0.004458
# [127]	eval-rmse:0.144191	train-rmse:0.004344
# [128]	eval-rmse:0.144215	train-rmse:0.00413
# [129]	eval-rmse:0.144109	train-rmse:0.004011
# [130]	eval-rmse:0.144377	train-rmse:0.003764
# [131]	eval-rmse:0.144374	train-rmse:0.003694
# [132]	eval-rmse:0.144479	train-rmse:0.003613
# [133]	eval-rmse:0.144365	train-rmse:0.003531
# [134]	eval-rmse:0.14522	train-rmse:0.00341
# [135]	eval-rmse:0.145217	train-rmse:0.00328
# [136]	eval-rmse:0.145183	train-rmse:0.00317
# [137]	eval-rmse:0.145071	train-rmse:0.003107
# [138]	eval-rmse:0.145098	train-rmse:0.003026
# [139]	eval-rmse:0.145093	train-rmse:0.002991
# [140]	eval-rmse:0.14504	train-rmse:0.002942
# [141]	eval-rmse:0.145038	train-rmse:0.002878
# [142]	eval-rmse:0.14506	train-rmse:0.00276
# [143]	eval-rmse:0.144885	train-rmse:0.002706
# [144]	eval-rmse:0.144852	train-rmse:0.002632
# [145]	eval-rmse:0.143914	train-rmse:0.002519
# [146]	eval-rmse:0.143958	train-rmse:0.002485
# [147]	eval-rmse:0.144618	train-rmse:0.002337
# [148]	eval-rmse:0.144653	train-rmse:0.002291
# [149]	eval-rmse:0.144649	train-rmse:0.002244
# [150]	eval-rmse:0.144649	train-rmse:0.002188
# [151]	eval-rmse:0.144647	train-rmse:0.002155
# [152]	eval-rmse:0.144645	train-rmse:0.0021
# [153]	eval-rmse:0.144761	train-rmse:0.002018
# [154]	eval-rmse:0.144244	train-rmse:0.001961
# [155]	eval-rmse:0.144065	train-rmse:0.001875
# [156]	eval-rmse:0.144036	train-rmse:0.001806
# [157]	eval-rmse:0.144082	train-rmse:0.001785
# [158]	eval-rmse:0.144077	train-rmse:0.001772
# [159]	eval-rmse:0.144091	train-rmse:0.001735
# [160]	eval-rmse:0.143612	train-rmse:0.001668
# [161]	eval-rmse:0.143616	train-rmse:0.001605
# [162]	eval-rmse:0.144379	train-rmse:0.001537
# [163]	eval-rmse:0.144324	train-rmse:0.001485
# [164]	eval-rmse:0.144322	train-rmse:0.001435
# [165]	eval-rmse:0.144227	train-rmse:0.001352
# [166]	eval-rmse:0.144256	train-rmse:0.001291
# [167]	eval-rmse:0.14425	train-rmse:0.001264
# [168]	eval-rmse:0.144257	train-rmse:0.001247
# [169]	eval-rmse:0.144264	train-rmse:0.001198
# [170]	eval-rmse:0.144686	train-rmse:0.001168
# [171]	eval-rmse:0.14459	train-rmse:0.001086
# [172]	eval-rmse:0.144588	train-rmse:0.001074
# [173]	eval-rmse:0.144589	train-rmse:0.001058
# [174]	eval-rmse:0.144586	train-rmse:0.001039
# [175]	eval-rmse:0.144584	train-rmse:0.001023
# [176]	eval-rmse:0.144583	train-rmse:0.001023
# [177]	eval-rmse:0.144583	train-rmse:0.001023
# [178]	eval-rmse:0.144582	train-rmse:0.001023
# [179]	eval-rmse:0.144582	train-rmse:0.001023
# [180]	eval-rmse:0.144582	train-rmse:0.001023
# [181]	eval-rmse:0.144582	train-rmse:0.001023
# [182]	eval-rmse:0.144582	train-rmse:0.001023
# [183]	eval-rmse:0.144582	train-rmse:0.001023
# [184]	eval-rmse:0.144582	train-rmse:0.001023
# [185]	eval-rmse:0.144582	train-rmse:0.001023
# [186]	eval-rmse:0.144582	train-rmse:0.001023
# [187]	eval-rmse:0.144582	train-rmse:0.001023
# [188]	eval-rmse:0.144582	train-rmse:0.001023
# [189]	eval-rmse:0.144582	train-rmse:0.001023
# [190]	eval-rmse:0.144582	train-rmse:0.001023
# [191]	eval-rmse:0.144582	train-rmse:0.001023
# [192]	eval-rmse:0.144582	train-rmse:0.001023
# [193]	eval-rmse:0.144582	train-rmse:0.001023
# [194]	eval-rmse:0.144582	train-rmse:0.001023
# [195]	eval-rmse:0.144582	train-rmse:0.001023
# [196]	eval-rmse:0.144582	train-rmse:0.001023
# [197]	eval-rmse:0.144582	train-rmse:0.001023
# [198]	eval-rmse:0.144582	train-rmse:0.001023
# [199]	eval-rmse:0.144582	train-rmse:0.001023
# [200]	eval-rmse:0.144582	train-rmse:0.001023
# [201]	eval-rmse:0.144582	train-rmse:0.001023
# [202]	eval-rmse:0.144582	train-rmse:0.001023
# [203]	eval-rmse:0.144582	train-rmse:0.001023
# [204]	eval-rmse:0.144582	train-rmse:0.001023
# [205]	eval-rmse:0.144582	train-rmse:0.001023
# [206]	eval-rmse:0.144582	train-rmse:0.001023
# [207]	eval-rmse:0.144582	train-rmse:0.001023
# [208]	eval-rmse:0.144582	train-rmse:0.001023
# [209]	eval-rmse:0.144582	train-rmse:0.001023
# [210]	eval-rmse:0.144582	train-rmse:0.001023
# [211]	eval-rmse:0.144582	train-rmse:0.001023
# [212]	eval-rmse:0.144582	train-rmse:0.001023
# [213]	eval-rmse:0.144582	train-rmse:0.001023
# [214]	eval-rmse:0.144582	train-rmse:0.001023
# [215]	eval-rmse:0.144582	train-rmse:0.001023
# [216]	eval-rmse:0.144582	train-rmse:0.001023
# [217]	eval-rmse:0.144582	train-rmse:0.001023
# [218]	eval-rmse:0.144582	train-rmse:0.001023
# [219]	eval-rmse:0.144582	train-rmse:0.001023
# [220]	eval-rmse:0.144582	train-rmse:0.001023
# [221]	eval-rmse:0.144582	train-rmse:0.001023
# [222]	eval-rmse:0.144582	train-rmse:0.001023
# [223]	eval-rmse:0.144582	train-rmse:0.001023
# [224]	eval-rmse:0.144582	train-rmse:0.001023
# [225]	eval-rmse:0.144582	train-rmse:0.001023
# [226]	eval-rmse:0.144582	train-rmse:0.001023
# [227]	eval-rmse:0.144582	train-rmse:0.001023
# [228]	eval-rmse:0.144582	train-rmse:0.001023
# [229]	eval-rmse:0.144582	train-rmse:0.001023
# [230]	eval-rmse:0.144582	train-rmse:0.001023
# [231]	eval-rmse:0.144582	train-rmse:0.001023
# [232]	eval-rmse:0.144582	train-rmse:0.001023
# [233]	eval-rmse:0.144582	train-rmse:0.001023
# [234]	eval-rmse:0.144582	train-rmse:0.001023
# [235]	eval-rmse:0.144582	train-rmse:0.001023
# [236]	eval-rmse:0.144582	train-rmse:0.001023
# [237]	eval-rmse:0.144582	train-rmse:0.001023
# [238]	eval-rmse:0.144582	train-rmse:0.001023
# [239]	eval-rmse:0.144582	train-rmse:0.001023
# [240]	eval-rmse:0.144582	train-rmse:0.001023
# [241]	eval-rmse:0.144582	train-rmse:0.001023
# [242]	eval-rmse:0.144582	train-rmse:0.001023
# [243]	eval-rmse:0.144582	train-rmse:0.001023
# [244]	eval-rmse:0.144582	train-rmse:0.001023
# [245]	eval-rmse:0.144582	train-rmse:0.001023
# [246]	eval-rmse:0.144582	train-rmse:0.001023
# [247]	eval-rmse:0.144582	train-rmse:0.001023
# [248]	eval-rmse:0.144582	train-rmse:0.001023
# [249]	eval-rmse:0.144582	train-rmse:0.001023
# [250]	eval-rmse:0.144582	train-rmse:0.001023
# [251]	eval-rmse:0.144582	train-rmse:0.001023
# [252]	eval-rmse:0.144582	train-rmse:0.001023
# [253]	eval-rmse:0.144582	train-rmse:0.001023
# [254]	eval-rmse:0.144582	train-rmse:0.001023
# [255]	eval-rmse:0.144582	train-rmse:0.001023
# [256]	eval-rmse:0.144582	train-rmse:0.001023
# [257]	eval-rmse:0.144582	train-rmse:0.001023
# [258]	eval-rmse:0.144582	train-rmse:0.001023
# [259]	eval-rmse:0.144582	train-rmse:0.001023
# [260]	eval-rmse:0.144582	train-rmse:0.001023
# [261]	eval-rmse:0.144582	train-rmse:0.001023
# [262]	eval-rmse:0.144582	train-rmse:0.001023
# [263]	eval-rmse:0.144582	train-rmse:0.001023
# [264]	eval-rmse:0.144582	train-rmse:0.001023
# [265]	eval-rmse:0.144582	train-rmse:0.001023
# [266]	eval-rmse:0.144582	train-rmse:0.001023
# [267]	eval-rmse:0.144582	train-rmse:0.001023
# [268]	eval-rmse:0.144582	train-rmse:0.001023
# [269]	eval-rmse:0.144582	train-rmse:0.001023
# [270]	eval-rmse:0.144582	train-rmse:0.001023
# [271]	eval-rmse:0.144582	train-rmse:0.001023
# [272]	eval-rmse:0.144582	train-rmse:0.001023
# [273]	eval-rmse:0.144582	train-rmse:0.001023
# [274]	eval-rmse:0.144582	train-rmse:0.001023
# [275]	eval-rmse:0.144582	train-rmse:0.001023
# [276]	eval-rmse:0.144582	train-rmse:0.001023
# [277]	eval-rmse:0.144582	train-rmse:0.001023
# [278]	eval-rmse:0.144582	train-rmse:0.001023
# [279]	eval-rmse:0.144582	train-rmse:0.001023
# [280]	eval-rmse:0.144582	train-rmse:0.001023
# [281]	eval-rmse:0.144582	train-rmse:0.001023
# [282]	eval-rmse:0.144582	train-rmse:0.001023
# [283]	eval-rmse:0.144582	train-rmse:0.001023
# [284]	eval-rmse:0.144582	train-rmse:0.001023
# [285]	eval-rmse:0.144582	train-rmse:0.001023
# [286]	eval-rmse:0.144582	train-rmse:0.001023
# [287]	eval-rmse:0.144582	train-rmse:0.001023
# [288]	eval-rmse:0.144582	train-rmse:0.001023
# [289]	eval-rmse:0.144582	train-rmse:0.001023
# [290]	eval-rmse:0.144582	train-rmse:0.001023
# [291]	eval-rmse:0.144582	train-rmse:0.001023
# [292]	eval-rmse:0.144582	train-rmse:0.001023
# [293]	eval-rmse:0.144582	train-rmse:0.001023
# [294]	eval-rmse:0.144582	train-rmse:0.001023
# [295]	eval-rmse:0.144582	train-rmse:0.001023
# [296]	eval-rmse:0.144582	train-rmse:0.001023
# [297]	eval-rmse:0.144582	train-rmse:0.001023
# [298]	eval-rmse:0.144582	train-rmse:0.001023
# [299]	eval-rmse:0.144582	train-rmse:0.001023
# [300]	eval-rmse:0.144582	train-rmse:0.001023
# [301]	eval-rmse:0.144582	train-rmse:0.001023
# [302]	eval-rmse:0.144582	train-rmse:0.001023
# [303]	eval-rmse:0.144582	train-rmse:0.001023
# [304]	eval-rmse:0.144582	train-rmse:0.001023
# [305]	eval-rmse:0.144582	train-rmse:0.001023
# [306]	eval-rmse:0.144582	train-rmse:0.001023
# [307]	eval-rmse:0.144582	train-rmse:0.001023
# [308]	eval-rmse:0.144582	train-rmse:0.001023
# [309]	eval-rmse:0.144582	train-rmse:0.001023
# [310]	eval-rmse:0.144582	train-rmse:0.001023
# [311]	eval-rmse:0.144582	train-rmse:0.001023
# [312]	eval-rmse:0.144582	train-rmse:0.001023
# [313]	eval-rmse:0.144582	train-rmse:0.001023
# [314]	eval-rmse:0.144582	train-rmse:0.001023
# [315]	eval-rmse:0.144582	train-rmse:0.001023
# [316]	eval-rmse:0.144582	train-rmse:0.001023
# [317]	eval-rmse:0.144582	train-rmse:0.001023
# [318]	eval-rmse:0.144582	train-rmse:0.001023
# [319]	eval-rmse:0.144582	train-rmse:0.001023
# [320]	eval-rmse:0.144582	train-rmse:0.001023
# [321]	eval-rmse:0.144582	train-rmse:0.001023
# [322]	eval-rmse:0.144582	train-rmse:0.001023
# [323]	eval-rmse:0.144582	train-rmse:0.001023
# [324]	eval-rmse:0.144582	train-rmse:0.001023
# [325]	eval-rmse:0.144582	train-rmse:0.001023
# [326]	eval-rmse:0.144582	train-rmse:0.001023
# [327]	eval-rmse:0.144582	train-rmse:0.001023
# [328]	eval-rmse:0.144582	train-rmse:0.001023
# [329]	eval-rmse:0.144582	train-rmse:0.001023
# [330]	eval-rmse:0.144582	train-rmse:0.001023
# [331]	eval-rmse:0.144582	train-rmse:0.001023
# [332]	eval-rmse:0.144582	train-rmse:0.001023
# [333]	eval-rmse:0.144582	train-rmse:0.001023
# [334]	eval-rmse:0.144582	train-rmse:0.001023
# [335]	eval-rmse:0.144582	train-rmse:0.001023
# [336]	eval-rmse:0.144582	train-rmse:0.001023
# [337]	eval-rmse:0.144582	train-rmse:0.001023
# [338]	eval-rmse:0.144582	train-rmse:0.001023
# [339]	eval-rmse:0.144582	train-rmse:0.001023
# [340]	eval-rmse:0.144582	train-rmse:0.001023
# [341]	eval-rmse:0.144582	train-rmse:0.001023
# [342]	eval-rmse:0.144582	train-rmse:0.001023
# [343]	eval-rmse:0.144582	train-rmse:0.001023
# [344]	eval-rmse:0.144582	train-rmse:0.001023
# [345]	eval-rmse:0.144582	train-rmse:0.001023
# [346]	eval-rmse:0.144582	train-rmse:0.001023
# [347]	eval-rmse:0.144582	train-rmse:0.001023
# [348]	eval-rmse:0.144582	train-rmse:0.001023
# [349]	eval-rmse:0.144582	train-rmse:0.001023
# [350]	eval-rmse:0.144582	train-rmse:0.001023
# [351]	eval-rmse:0.144582	train-rmse:0.001023
# [352]	eval-rmse:0.144582	train-rmse:0.001023
# [353]	eval-rmse:0.144582	train-rmse:0.001023
# [354]	eval-rmse:0.144582	train-rmse:0.001023
# [355]	eval-rmse:0.144582	train-rmse:0.001023
# [356]	eval-rmse:0.144582	train-rmse:0.001023
# [357]	eval-rmse:0.144582	train-rmse:0.001023
# [358]	eval-rmse:0.144582	train-rmse:0.001023
# [359]	eval-rmse:0.144582	train-rmse:0.001023
# [360]	eval-rmse:0.144582	train-rmse:0.001023
# [361]	eval-rmse:0.144582	train-rmse:0.001023
# [362]	eval-rmse:0.144582	train-rmse:0.001023
# [363]	eval-rmse:0.144582	train-rmse:0.001023
# [364]	eval-rmse:0.144582	train-rmse:0.001023
# [365]	eval-rmse:0.144582	train-rmse:0.001023
# [366]	eval-rmse:0.144582	train-rmse:0.001023
# [367]	eval-rmse:0.144582	train-rmse:0.001023
# [368]	eval-rmse:0.144582	train-rmse:0.001023
# [369]	eval-rmse:0.144582	train-rmse:0.001023
# [370]	eval-rmse:0.144582	train-rmse:0.001023
# [371]	eval-rmse:0.144582	train-rmse:0.001023
# [372]	eval-rmse:0.144582	train-rmse:0.001023
# [373]	eval-rmse:0.144582	train-rmse:0.001023
# [374]	eval-rmse:0.144582	train-rmse:0.001023
# [375]	eval-rmse:0.144582	train-rmse:0.001023
# [376]	eval-rmse:0.144582	train-rmse:0.001023
# [377]	eval-rmse:0.144582	train-rmse:0.001023
# [378]	eval-rmse:0.144582	train-rmse:0.001023
# [379]	eval-rmse:0.144582	train-rmse:0.001023
# [380]	eval-rmse:0.144582	train-rmse:0.001023
# [381]	eval-rmse:0.144582	train-rmse:0.001023
# [382]	eval-rmse:0.144582	train-rmse:0.001023
# [383]	eval-rmse:0.144582	train-rmse:0.001023
# [384]	eval-rmse:0.144582	train-rmse:0.001023
# [385]	eval-rmse:0.144582	train-rmse:0.001023
# [386]	eval-rmse:0.144582	train-rmse:0.001023
# [387]	eval-rmse:0.144582	train-rmse:0.001023
# [388]	eval-rmse:0.144582	train-rmse:0.001023
# [389]	eval-rmse:0.144582	train-rmse:0.001023
# [390]	eval-rmse:0.144582	train-rmse:0.001023
# [391]	eval-rmse:0.144582	train-rmse:0.001023
# [392]	eval-rmse:0.144582	train-rmse:0.001023
# [393]	eval-rmse:0.144582	train-rmse:0.001023
# [394]	eval-rmse:0.144582	train-rmse:0.001023
# [395]	eval-rmse:0.144582	train-rmse:0.001023
# [396]	eval-rmse:0.144582	train-rmse:0.001023
# [397]	eval-rmse:0.144582	train-rmse:0.001023
# [398]	eval-rmse:0.144582	train-rmse:0.001023
# [399]	eval-rmse:0.144582	train-rmse:0.001023
# [400]	eval-rmse:0.144582	train-rmse:0.001023
# [401]	eval-rmse:0.144582	train-rmse:0.001023
# [402]	eval-rmse:0.144582	train-rmse:0.001023
# [403]	eval-rmse:0.144582	train-rmse:0.001023
# [404]	eval-rmse:0.144582	train-rmse:0.001023
# [405]	eval-rmse:0.144582	train-rmse:0.001023
# [406]	eval-rmse:0.144582	train-rmse:0.001023
# [407]	eval-rmse:0.144582	train-rmse:0.001023
# [408]	eval-rmse:0.144582	train-rmse:0.001023
# [409]	eval-rmse:0.144582	train-rmse:0.001023
# [410]	eval-rmse:0.144582	train-rmse:0.001023
# [411]	eval-rmse:0.144582	train-rmse:0.001023
# [412]	eval-rmse:0.144582	train-rmse:0.001023
# [413]	eval-rmse:0.144582	train-rmse:0.001023
# [414]	eval-rmse:0.144582	train-rmse:0.001023
# [415]	eval-rmse:0.144582	train-rmse:0.001023
# [416]	eval-rmse:0.144582	train-rmse:0.001023
# [417]	eval-rmse:0.144582	train-rmse:0.001023
# [418]	eval-rmse:0.144582	train-rmse:0.001023
# [419]	eval-rmse:0.144582	train-rmse:0.001023
# [420]	eval-rmse:0.144582	train-rmse:0.001023
# [421]	eval-rmse:0.144582	train-rmse:0.001023
# [422]	eval-rmse:0.144582	train-rmse:0.001023
# [423]	eval-rmse:0.144582	train-rmse:0.001023
# [424]	eval-rmse:0.144582	train-rmse:0.001023
# [425]	eval-rmse:0.144582	train-rmse:0.001023
# [426]	eval-rmse:0.144582	train-rmse:0.001023
# [427]	eval-rmse:0.144582	train-rmse:0.001023
# [428]	eval-rmse:0.144582	train-rmse:0.001023
# [429]	eval-rmse:0.144582	train-rmse:0.001023
# [430]	eval-rmse:0.144582	train-rmse:0.001023
# [431]	eval-rmse:0.144582	train-rmse:0.001023
# [432]	eval-rmse:0.144582	train-rmse:0.001023
# [433]	eval-rmse:0.144582	train-rmse:0.001023
# [434]	eval-rmse:0.144582	train-rmse:0.001023
# [435]	eval-rmse:0.144582	train-rmse:0.001023
# [436]	eval-rmse:0.144582	train-rmse:0.001023
# [437]	eval-rmse:0.144582	train-rmse:0.001023
# [438]	eval-rmse:0.144582	train-rmse:0.001023
# [439]	eval-rmse:0.144582	train-rmse:0.001023
# [440]	eval-rmse:0.144582	train-rmse:0.001023
# [441]	eval-rmse:0.144582	train-rmse:0.001023
# [442]	eval-rmse:0.144582	train-rmse:0.001023
# [443]	eval-rmse:0.144582	train-rmse:0.001023
# [444]	eval-rmse:0.144582	train-rmse:0.001023
# [445]	eval-rmse:0.144582	train-rmse:0.001023
# [446]	eval-rmse:0.144582	train-rmse:0.001023
# [447]	eval-rmse:0.144582	train-rmse:0.001023
# [448]	eval-rmse:0.144582	train-rmse:0.001023
# [449]	eval-rmse:0.144582	train-rmse:0.001023
# [450]	eval-rmse:0.144582	train-rmse:0.001023
# [451]	eval-rmse:0.144582	train-rmse:0.001023
# [452]	eval-rmse:0.144582	train-rmse:0.001023
# [453]	eval-rmse:0.144582	train-rmse:0.001023
# [454]	eval-rmse:0.144582	train-rmse:0.001023
# [455]	eval-rmse:0.144582	train-rmse:0.001023
# [456]	eval-rmse:0.144582	train-rmse:0.001023
# [457]	eval-rmse:0.144582	train-rmse:0.001023
# [458]	eval-rmse:0.144582	train-rmse:0.001023
# [459]	eval-rmse:0.144582	train-rmse:0.001023
# [460]	eval-rmse:0.144582	train-rmse:0.001023
# [461]	eval-rmse:0.144582	train-rmse:0.001023
# [462]	eval-rmse:0.144582	train-rmse:0.001023
# [463]	eval-rmse:0.144582	train-rmse:0.001023
# [464]	eval-rmse:0.144582	train-rmse:0.001023
# [465]	eval-rmse:0.144582	train-rmse:0.001023
# [466]	eval-rmse:0.144582	train-rmse:0.001023
# [467]	eval-rmse:0.144582	train-rmse:0.001023
# [468]	eval-rmse:0.144582	train-rmse:0.001023
# [469]	eval-rmse:0.144582	train-rmse:0.001023
# [470]	eval-rmse:0.144582	train-rmse:0.001023
# [471]	eval-rmse:0.144582	train-rmse:0.001023
# [472]	eval-rmse:0.144582	train-rmse:0.001023
# [473]	eval-rmse:0.144582	train-rmse:0.001023
# [474]	eval-rmse:0.144582	train-rmse:0.001023
# [475]	eval-rmse:0.144582	train-rmse:0.001023
# [476]	eval-rmse:0.144582	train-rmse:0.001023
# [477]	eval-rmse:0.144582	train-rmse:0.001023
# [478]	eval-rmse:0.144582	train-rmse:0.001023
# [479]	eval-rmse:0.144582	train-rmse:0.001023
# [480]	eval-rmse:0.144582	train-rmse:0.001023
# [481]	eval-rmse:0.144582	train-rmse:0.001023
# [482]	eval-rmse:0.144582	train-rmse:0.001023
# [483]	eval-rmse:0.144582	train-rmse:0.001023
# [484]	eval-rmse:0.144582	train-rmse:0.001023
# [485]	eval-rmse:0.144582	train-rmse:0.001023
# [486]	eval-rmse:0.144582	train-rmse:0.001023
# [487]	eval-rmse:0.144582	train-rmse:0.001023
# [488]	eval-rmse:0.144582	train-rmse:0.001023
# [489]	eval-rmse:0.144582	train-rmse:0.001023
# [490]	eval-rmse:0.144582	train-rmse:0.001023
# [491]	eval-rmse:0.144582	train-rmse:0.001023
# [492]	eval-rmse:0.144582	train-rmse:0.001023
# [493]	eval-rmse:0.144582	train-rmse:0.001023
# [494]	eval-rmse:0.144582	train-rmse:0.001023
# [495]	eval-rmse:0.144582	train-rmse:0.001023
# [496]	eval-rmse:0.144582	train-rmse:0.001023
# [497]	eval-rmse:0.144582	train-rmse:0.001023
# [498]	eval-rmse:0.144582	train-rmse:0.001023
# [499]	eval-rmse:0.144582	train-rmse:0.001023

# %%
xgb.plot_importance(bst)

# %%
ypred = bst.predict(dtest)

# %%
print(ypred.shape)
print(testing_labels.shape)
# Out:
# (189,)
# (189, 1)
