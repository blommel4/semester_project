# %%
import xgboost as xgb
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import graphviz
import numpy as np
from sklearn import preprocessing

# %%
full_results = pd.read_csv('full_results.csv')
full_stats = pd.read_csv('FullKenPom_pt.csv')

print(full_results.shape)
print(full_stats.shape)
# Out:
# (1112, 11)
# (1129, 27)

# %%
###mask test and train data###
res_test_mask = (full_results['Year'] == 2016) | (full_results['Year'] == 2017) | (full_results['Year'] == 2018)
stats_test_mask = (full_stats['Season'] == 2016) | (full_stats['Season'] == 2017) | (full_stats['Season'] == 2018)
res_train_mask = (full_results['Year'] < 2016)
stats_train_mask = (full_stats['Season'] < 2016)

res_data_test = full_results[res_test_mask]
stats_data_test = full_stats[stats_test_mask]
res_data_train = full_results[res_train_mask]
stats_data_train = full_stats[stats_train_mask]

#reindex all of them
res_data_test = res_data_test.reset_index()
stats_data_test = stats_data_test.reset_index()
res_data_train = res_data_train.reset_index()
stats_data_train = stats_data_train.reset_index()

for i in range(len(res_data_test)):
    if res_data_test['Region Name'][i] == "First Four":
        res_data_test = res_data_test.drop(i)
for i in range(len(res_data_train)):
    if res_data_train['Region Name'][i] == "First Four":
        res_data_train = res_data_train.drop(i)
        
#reindex all of them
res_data_test = res_data_test.reset_index()
stats_data_test = stats_data_test.reset_index()
res_data_train = res_data_train.reset_index()
stats_data_train = stats_data_train.reset_index()

res_data_train.head()

#res_data_test.tail()
#stats_data_test.tail()
#res_data_train.tail()
#stats_data_train.tail()
# Out:
#    level_0  index  Unnamed: 0  Year  Round  Region Number Region Name  SeedA  \
# 0        1      1           1  2002      1              1       South      1
# 1        2      2           2  2002      1              1       South      2
# 2        3      3           3  2002      1              1       South      3
# 3        4      4           4  2002      1              1       South      4
# 4        5      5           5  2002      1              1       South      5
#
#    ScoreA       TeamA                   TeamB  ScoreB  SeedB
# 0      84        Duke                Winthrop      37     16
# 1      86     Alabama        Florida Atlantic      78     15
# 2      71  Pittsburgh  Central Connecticut St      54     14
# 3      89         USC          UNC Wilmington      93     13
# 4      75     Indiana                    Utah      56     12

# %%
#these names match the kenpom stats csv
stats_vec = ["AdjTempo",
            "AdjOE",
            "AdjDE",
            "AdjEM",
            "seed",
            "ConfTournament",
            "SOSAdjEM",
            "NCSOSAdjEM",
            "O-D_eFG_Pct",
            "D-O_TO_Pct",
            "O-D_OR_Pct",
            "O-D_FT_Rate",
            "LastTenRecord"]

print(len(stats_vec))
# Out:
# 13

# %%
# Move training data into 2 numpy arrays - data and labels (results)
N = len(res_data_train)

training_data = np.zeros((N,13))
training_labels = np.zeros((N,1))

for i in range(len(res_data_train)):
    year = res_data_train['Year'][i]
    teamA = res_data_train['TeamA'][i]
    teamB = res_data_train['TeamB'][i]
    score_diff = res_data_train['ScoreA'][i] - res_data_train['ScoreB'][i]
    for k in range(len(stats_data_train)):
        if ((stats_data_train['Season'][k] == year) and (stats_data_train['TeamName'][k] == teamA)):
            indexA = k
            break
            
    for k in range(len(stats_data_train)):
        if ((stats_data_train['Season'][k] == year) and (stats_data_train['TeamName'][k] == teamB)):
            indexB = k
            break
    for s in range(len(stats_vec)):
        stat = stats_vec[s]
        training_data[i][s] = stats_data_train[stat][indexA] - stats_data_train[stat][indexB]
    
    if (score_diff > 0): # team A won
        training_labels[i][0] = 1
        print("Winner:",teamA)
        print("Loser: ",teamB,'\n')
    else:
        training_labels[i][0] = 0 #team B won
        print("Winner:",teamB)
        print("Loser: ",teamA,'\n')
# Out:
# Winner: Duke
# Loser:  Winthrop
#
# Winner: Alabama
# Loser:  Florida Atlantic
#
# Winner: Pittsburgh
# Loser:  Central Connecticut St
#
# Winner: UNC Wilmington
# Loser:  USC
#
# Winner: Indiana
# Loser:  Utah
#
# Winner: California
# Loser:  Pennsylvania
#
# Winner: Kent St
# Loser:  Oklahoma St
#
# Winner: Notre Dame
# Loser:  Charlotte
#
# Winner: Cincinnati
# Loser:  Boston University
#
# Winner: Oklahoma
# Loser:  Illinois Chicago
#
# Winner: Arizona
# Loser:  Santa Barbara
#
# Winner: Ohio St
# Loser:  Davidson
#
# Winner: Missouri
# Loser:  Miami
#
# Winner: Wyoming
# Loser:  Gonzaga
#
# Winner: Xavier
# Loser:  Hawaii
#
# Winner: UCLA
# Loser:  Ole Miss
#
# Winner: Maryland
# Loser:  Siena
#
# Winner: Connecticut
# Loser:  Hampton
#
# Winner: Georgia
# Loser:  Murray St
#
# Winner: Kentucky
# Loser:  Valparaiso
#
# Winner: Tulsa
# Loser:  Marquette
#
# Winner: Southern Illinois
# Loser:  Texas Tech
#
# Winner: NC State
# Loser:  Michigan St
#
# Winner: Wisconsin
# Loser:  St Johns
#
# Winner: Kansas
# Loser:  Holy Cross
#
# Winner: Oregon
# Loser:  Montana
#
# Winner: Mississippi St
# Loser:  McNeese St
#
# Winner: Illinois
# Loser:  San Diego St
#
# Winner: Creighton
# Loser:  Florida
#
# Winner: Texas
# Loser:  Boston College
#
# Winner: Wake Forest
# Loser:  Pepperdine
#
# Winner: Stanford
# Loser:  Western Kentucky
#
# Winner: Duke
# Loser:  Notre Dame
#
# Winner: Kent St
# Loser:  Alabama
#
# Winner: Pittsburgh
# Loser:  California
#
# Winner: Indiana
# Loser:  UNC Wilmington
#
# Winner: UCLA
# Loser:  Cincinnati
#
# Winner: Oklahoma
# Loser:  Xavier
#
# Winner: Arizona
# Loser:  Wyoming
#
# Winner: Missouri
# Loser:  Ohio St
#
# Winner: Maryland
# Loser:  Wisconsin
#
# Winner: Connecticut
# Loser:  NC State
#
# Winner: Southern Illinois
# Loser:  Georgia
#
# Winner: Kentucky
# Loser:  Tulsa
#
# Winner: Kansas
# Loser:  Stanford
#
# Winner: Oregon
# Loser:  Wake Forest
#
# Winner: Texas
# Loser:  Mississippi St
#
# Winner: Illinois
# Loser:  Creighton
#
# Winner: Indiana
# Loser:  Duke
#
# Winner: Kent St
# Loser:  Pittsburgh
#
# Winner: Missouri
# Loser:  UCLA
#
# Winner: Oklahoma
# Loser:  Arizona
#
# Winner: Maryland
# Loser:  Kentucky
#
# Winner: Connecticut
# Loser:  Southern Illinois
#
# Winner: Kansas
# Loser:  Illinois
#
# Winner: Oregon
# Loser:  Texas
#
# Winner: Indiana
# Loser:  Kent St
#
# Winner: Oklahoma
# Loser:  Missouri
#
# Winner: Maryland
# Loser:  Connecticut
#
# Winner: Kansas
# Loser:  Oregon
#
# Winner: Indiana
# Loser:  Oklahoma
#
# Winner: Maryland
# Loser:  Kansas
#
# Winner: Maryland
# Loser:  Indiana
#
# Winner: Kentucky
# Loser:  IUPUI
#
# Winner: Pittsburgh
# Loser:  Wagner
#
# Winner: Marquette
# Loser:  Holy Cross
#
# Winner: Tulsa
# Loser:  Dayton
#
# Winner: Wisconsin
# Loser:  Weber St
#
# Winner: Missouri
# Loser:  Southern Illinois
#
# Winner: Indiana
# Loser:  Alabama
#
# Winner: Utah
# Loser:  Oregon
#
# Winner: Arizona
# Loser:  Vermont
#
# Winner: Kansas
# Loser:  Utah St
#
# Winner: Duke
# Loser:  Colorado St
#
# Winner: Illinois
# Loser:  Western Kentucky
#
# Winner: Notre Dame
# Loser:  Wisconsin Milwaukee
#
# Winner: Central Michigan
# Loser:  Creighton
#
# Winner: Arizona St
# Loser:  Memphis
#
# Winner: Gonzaga
# Loser:  Cincinnati
#
# Winner: Texas
# Loser:  UNC Asheville
#
# Winner: Florida
# Loser:  Sam Houston St
#
# Winner: Xavier
# Loser:  Troy
#
# Winner: Stanford
# Loser:  San Diego
#
# Winner: Connecticut
# Loser:  BYU
#
# Winner: Maryland
# Loser:  UNC Wilmington
#
# Winner: Michigan St
# Loser:  Colorado
#
# Winner: Purdue
# Loser:  LSU
#
# Winner: Oklahoma
# Loser:  South Carolina St
#
# Winner: Wake Forest
# Loser:  East Tennessee St
#
# Winner: Syracuse
# Loser:  Manhattan
#
# Winner: Louisville
# Loser:  Austin Peay
#
# Winner: Butler
# Loser:  Mississippi St
#
# Winner: Oklahoma St
# Loser:  Pennsylvania
#
# Winner: Auburn
# Loser:  St Josephs
#
# Winner: California
# Loser:  NC State
#
# Winner: Kentucky
# Loser:  Utah
#
# Winner: Pittsburgh
# Loser:  Indiana
#
# Winner: Marquette
# Loser:  Missouri
#
# Winner: Wisconsin
# Loser:  Tulsa
#
# Winner: Arizona
# Loser:  Gonzaga
#
# Winner: Kansas
# Loser:  Arizona St
#
# Winner: Duke
# Loser:  Central Michigan
#
# Winner: Notre Dame
# Loser:  Illinois
#
# Winner: Texas
# Loser:  Purdue
#
# Winner: Michigan St
# Loser:  Florida
#
# Winner: Maryland
# Loser:  Xavier
#
# Winner: Connecticut
# Loser:  Stanford
#
# Winner: Oklahoma
# Loser:  California
#
# Winner: Auburn
# Loser:  Wake Forest
#
# Winner: Syracuse
# Loser:  Oklahoma St
#
# Winner: Butler
# Loser:  Louisville
#
# Winner: Kentucky
# Loser:  Wisconsin
#
# Winner: Marquette
# Loser:  Pittsburgh
#
# Winner: Arizona
# Loser:  Notre Dame
#
# Winner: Kansas
# Loser:  Duke
#
# Winner: Texas
# Loser:  Connecticut
#
# Winner: Michigan St
# Loser:  Maryland
#
# Winner: Oklahoma
# Loser:  Butler
#
# Winner: Syracuse
# Loser:  Auburn
#
# Winner: Marquette
# Loser:  Kentucky
#
# Winner: Kansas
# Loser:  Arizona
#
# Winner: Texas
# Loser:  Michigan St
#
# Winner: Syracuse
# Loser:  Oklahoma
#
# Winner: Kansas
# Loser:  Marquette
#
# Winner: Syracuse
# Loser:  Texas
#
# Winner: Syracuse
# Loser:  Kansas
#
# Winner: Kentucky
# Loser:  Florida A&M
#
# Winner: Gonzaga
# Loser:  Valparaiso
#
# Winner: Georgia Tech
# Loser:  Northern Iowa
#
# Winner: Kansas
# Loser:  Illinois Chicago
#
# Winner: Pacific
# Loser:  Providence
#
# Winner: Boston College
# Loser:  Utah
#
# Winner: Nevada
# Loser:  Michigan St
#
# Winner: UAB
# Loser:  Washington
#
# Winner: St Josephs
# Loser:  Liberty
#
# Winner: Oklahoma St
# Loser:  Eastern Washington
#
# Winner: Pittsburgh
# Loser:  Central Florida
#
# Winner: Wake Forest
# Loser:  VCU
#
# Winner: Manhattan
# Loser:  Florida
#
# Winner: Wisconsin
# Loser:  Richmond
#
# Winner: Memphis
# Loser:  South Carolina
#
# Winner: Texas Tech
# Loser:  Charlotte
#
# Winner: Duke
# Loser:  Alabama St
#
# Winner: Mississippi St
# Loser:  Monmouth
#
# Winner: Texas
# Loser:  Princeton
#
# Winner: Cincinnati
# Loser:  East Tennessee St
#
# Winner: Illinois
# Loser:  Murray St
#
# Winner: North Carolina
# Loser:  Air Force
#
# Winner: Xavier
# Loser:  Louisville
#
# Winner: Seton Hall
# Loser:  Arizona
#
# Winner: Stanford
# Loser:  Texas San Antonio
#
# Winner: Connecticut
# Loser:  Vermont
#
# Winner: NC State
# Loser:  Louisiana Lafayette
#
# Winner: Maryland
# Loser:  UTEP
#
# Winner: Syracuse
# Loser:  BYU
#
# Winner: Vanderbilt
# Loser:  Western Michigan
#
# Winner: DePaul
# Loser:  Dayton
#
# Winner: Alabama
# Loser:  Southern Illinois
#
# Winner: UAB
# Loser:  Kentucky
#
# Winner: Nevada
# Loser:  Gonzaga
#
# Winner: Georgia Tech
# Loser:  Boston College
#
# Winner: Kansas
# Loser:  Pacific
#
# Winner: St Josephs
# Loser:  Texas Tech
#
# Winner: Oklahoma St
# Loser:  Memphis
#
# Winner: Pittsburgh
# Loser:  Wisconsin
#
# Winner: Wake Forest
# Loser:  Manhattan
#
# Winner: Duke
# Loser:  Seton Hall
#
# Winner: Xavier
# Loser:  Mississippi St
#
# Winner: Texas
# Loser:  North Carolina
#
# Winner: Illinois
# Loser:  Cincinnati
#
# Winner: Alabama
# Loser:  Stanford
#
# Winner: Connecticut
# Loser:  DePaul
#
# Winner: Vanderbilt
# Loser:  NC State
#
# Winner: Syracuse
# Loser:  Maryland
#
# Winner: Kansas
# Loser:  UAB
#
# Winner: Georgia Tech
# Loser:  Nevada
#
# Winner: St Josephs
# Loser:  Wake Forest
#
# Winner: Oklahoma St
# Loser:  Pittsburgh
#
# Winner: Duke
# Loser:  Illinois
#
# Winner: Xavier
# Loser:  Texas
#
# Winner: Alabama
# Loser:  Syracuse
#
# Winner: Connecticut
# Loser:  Vanderbilt
#
# Winner: Georgia Tech
# Loser:  Kansas
#
# Winner: Oklahoma St
# Loser:  St Josephs
#
# Winner: Duke
# Loser:  Xavier
#
# Winner: Connecticut
# Loser:  Alabama
#
# Winner: Georgia Tech
# Loser:  Oklahoma St
#
# Winner: Connecticut
# Loser:  Duke
#
# Winner: Connecticut
# Loser:  Georgia Tech
#
# Winner: Illinois
# Loser:  Fairleigh Dickinson
#
# Winner: Oklahoma St
# Loser:  Southeastern Louisiana
#
# Winner: Arizona
# Loser:  Utah St
#
# Winner: Boston College
# Loser:  Pennsylvania
#
# Winner: Wisconsin Milwaukee
# Loser:  Alabama
#
# Winner: UAB
# Loser:  LSU
#
# Winner: Southern Illinois
# Loser:  St Marys
#
# Winner: Nevada
# Loser:  Texas
#
# Winner: Washington
# Loser:  Montana
#
# Winner: Wake Forest
# Loser:  Chattanooga
#
# Winner: Gonzaga
# Loser:  Winthrop
#
# Winner: Louisville
# Loser:  Louisiana Lafayette
#
# Winner: Georgia Tech
# Loser:  George Washington
#
# Winner: Texas Tech
# Loser:  UCLA
#
# Winner: West Virginia
# Loser:  Creighton
#
# Winner: Pacific
# Loser:  Pittsburgh
#
# Winner: North Carolina
# Loser:  Oakland
#
# Winner: Connecticut
# Loser:  Central Florida
#
# Winner: Bucknell
# Loser:  Kansas
#
# Winner: Florida
# Loser:  Ohio
#
# Winner: Villanova
# Loser:  New Mexico
#
# Winner: Wisconsin
# Loser:  Northern Iowa
#
# Winner: NC State
# Loser:  Charlotte
#
# Winner: Iowa St
# Loser:  Minnesota
#
# Winner: Duke
# Loser:  Delaware St
#
# Winner: Kentucky
# Loser:  Eastern Kentucky
#
# Winner: Oklahoma
# Loser:  Niagara
#
# Winner: Vermont
# Loser:  Syracuse
#
# Winner: Michigan St
# Loser:  Old Dominion
#
# Winner: Utah
# Loser:  UTEP
#
# Winner: Cincinnati
# Loser:  Iowa
#
# Winner: Mississippi St
# Loser:  Stanford
#
# Winner: Illinois
# Loser:  Nevada
#
# Winner: Oklahoma St
# Loser:  Southern Illinois
#
# Winner: Arizona
# Loser:  UAB
#
# Winner: Wisconsin Milwaukee
# Loser:  Boston College
#
# Winner: Washington
# Loser:  Pacific
#
# Winner: West Virginia
# Loser:  Wake Forest
#
# Winner: Texas Tech
# Loser:  Gonzaga
#
# Winner: Louisville
# Loser:  Georgia Tech
#
# Winner: North Carolina
# Loser:  Iowa St
#
# Winner: NC State
# Loser:  Connecticut
#
# Winner: Wisconsin
# Loser:  Bucknell
#
# Winner: Villanova
# Loser:  Florida
#
# Winner: Duke
# Loser:  Mississippi St
#
# Winner: Kentucky
# Loser:  Cincinnati
#
# Winner: Utah
# Loser:  Oklahoma
#
# Winner: Michigan St
# Loser:  Vermont
#
# Winner: Illinois
# Loser:  Wisconsin Milwaukee
#
# Winner: Arizona
# Loser:  Oklahoma St
#
# Winner: Louisville
# Loser:  Washington
#
# Winner: West Virginia
# Loser:  Texas Tech
#
# Winner: North Carolina
# Loser:  Villanova
#
# Winner: Wisconsin
# Loser:  NC State
#
# Winner: Michigan St
# Loser:  Duke
#
# Winner: Kentucky
# Loser:  Utah
#
# Winner: Illinois
# Loser:  Arizona
#
# Winner: Louisville
# Loser:  West Virginia
#
# Winner: North Carolina
# Loser:  Wisconsin
#
# Winner: Michigan St
# Loser:  Kentucky
#
# Winner: Illinois
# Loser:  Louisville
#
# Winner: North Carolina
# Loser:  Michigan St
#
# Winner: North Carolina
# Loser:  Illinois
#
# Winner: Duke
# Loser:  Southern
#
# Winner: Texas
# Loser:  Pennsylvania
#
# Winner: Northwestern St
# Loser:  Iowa
#
# Winner: LSU
# Loser:  Iona
#
# Winner: Texas A&M
# Loser:  Syracuse
#
# Winner: West Virginia
# Loser:  Southern Illinois
#
# Winner: NC State
# Loser:  California
#
# Winner: George Washington
# Loser:  UNC Wilmington
#
# Winner: Memphis
# Loser:  Oral Roberts
#
# Winner: UCLA
# Loser:  Belmont
#
# Winner: Gonzaga
# Loser:  Xavier
#
# Winner: Bradley
# Loser:  Kansas
#
# Winner: Pittsburgh
# Loser:  Kent St
#
# Winner: Indiana
# Loser:  San Diego St
#
# Winner: Alabama
# Loser:  Marquette
#
# Winner: Bucknell
# Loser:  Arkansas
#
# Winner: Connecticut
# Loser:  Albany
#
# Winner: Tennessee
# Loser:  Winthrop
#
# Winner: North Carolina
# Loser:  Murray St
#
# Winner: Illinois
# Loser:  Air Force
#
# Winner: Washington
# Loser:  Utah St
#
# Winner: George Mason
# Loser:  Michigan St
#
# Winner: Wichita St
# Loser:  Seton Hall
#
# Winner: Kentucky
# Loser:  UAB
#
# Winner: Villanova
# Loser:  Monmouth
#
# Winner: Ohio St
# Loser:  Davidson
#
# Winner: Florida
# Loser:  South Alabama
#
# Winner: Boston College
# Loser:  Pacific
#
# Winner: Montana
# Loser:  Nevada
#
# Winner: Wisconsin Milwaukee
# Loser:  Oklahoma
#
# Winner: Georgetown
# Loser:  Northern Iowa
#
# Winner: Arizona
# Loser:  Wisconsin
#
# Winner: Duke
# Loser:  George Washington
#
# Winner: Texas
# Loser:  NC State
#
# Winner: West Virginia
# Loser:  Northwestern St
#
# Winner: LSU
# Loser:  Texas A&M
#
# Winner: Memphis
# Loser:  Bucknell
#
# Winner: UCLA
# Loser:  Alabama
#
# Winner: Gonzaga
# Loser:  Indiana
#
# Winner: Bradley
# Loser:  Pittsburgh
#
# Winner: Connecticut
# Loser:  Kentucky
#
# Winner: Wichita St
# Loser:  Tennessee
# Winner: George Mason
# Loser:  North Carolina
#
# Winner: Washington
# Loser:  Illinois
#
# Winner: Villanova
# Loser:  Arizona
#
# Winner: Georgetown
# Loser:  Ohio St
#
# Winner: Florida
# Loser:  Wisconsin Milwaukee
#
# Winner: Boston College
# Loser:  Montana
#
# Winner: LSU
# Loser:  Duke
#
# Winner: Texas
# Loser:  West Virginia
#
# Winner: Memphis
# Loser:  Bradley
#
# Winner: UCLA
# Loser:  Gonzaga
#
# Winner: Connecticut
# Loser:  Washington
#
# Winner: George Mason
# Loser:  Wichita St
#
# Winner: Villanova
# Loser:  Boston College
#
# Winner: Florida
# Loser:  Georgetown
#
# Winner: LSU
# Loser:  Texas
#
# Winner: UCLA
# Loser:  Memphis
#
# Winner: George Mason
# Loser:  Connecticut
#
# Winner: Florida
# Loser:  Villanova
#
# Winner: UCLA
# Loser:  LSU
#
# Winner: Florida
# Loser:  George Mason
#
# Winner: Florida
# Loser:  UCLA
#
# Winner: Florida
# Loser:  Jackson St
#
# Winner: Wisconsin
# Loser:  Texas A&M Corpus Christi
#
# Winner: Oregon
# Loser:  Miami Ohio
#
# Winner: Maryland
# Loser:  Davidson
#
# Winner: Butler
# Loser:  Old Dominion
#
# Winner: Winthrop
# Loser:  Notre Dame
#
# Winner: UNLV
# Loser:  Georgia Tech
#
# Winner: Purdue
# Loser:  Arizona
#
# Winner: Kansas
# Loser:  Niagara
#
# Winner: UCLA
# Loser:  Weber St
#
# Winner: Pittsburgh
# Loser:  Wright St
#
# Winner: Southern Illinois
# Loser:  Holy Cross
#
# Winner: Virginia Tech
# Loser:  Illinois
#
# Winner: VCU
# Loser:  Duke
#
# Winner: Indiana
# Loser:  Gonzaga
#
# Winner: Kentucky
# Loser:  Villanova
#
# Winner: North Carolina
# Loser:  Eastern Kentucky
#
# Winner: Georgetown
# Loser:  Belmont
#
# Winner: Washington St
# Loser:  Oral Roberts
#
# Winner: Texas
# Loser:  New Mexico St
#
# Winner: USC
# Loser:  Arkansas
#
# Winner: Vanderbilt
# Loser:  George Washington
#
# Winner: Boston College
# Loser:  Texas Tech
#
# Winner: Michigan St
# Loser:  Marquette
#
# Winner: Ohio St
# Loser:  Central Connecticut St
#
# Winner: Memphis
# Loser:  North Texas
#
# Winner: Texas A&M
# Loser:  Pennsylvania
#
# Winner: Virginia
# Loser:  Albany
#
# Winner: Tennessee
# Loser:  Long Beach St
#
# Winner: Louisville
# Loser:  Stanford
#
# Winner: Nevada
# Loser:  Creighton
#
# Winner: Xavier
# Loser:  BYU
#
# Winner: Florida
# Loser:  Purdue
#
# Winner: UNLV
# Loser:  Wisconsin
#
# Winner: Oregon
# Loser:  Winthrop
#
# Winner: Butler
# Loser:  Maryland
#
# Winner: Kansas
# Loser:  Kentucky
#
# Winner: UCLA
# Loser:  Indiana
#
# Winner: Pittsburgh
# Loser:  VCU
#
# Winner: Southern Illinois
# Loser:  Virginia Tech
#
# Winner: North Carolina
# Loser:  Michigan St
#
# Winner: Georgetown
# Loser:  Boston College
#
# Winner: Vanderbilt
# Loser:  Washington St
#
# Winner: USC
# Loser:  Texas
#
# Winner: Ohio St
# Loser:  Xavier
#
# Winner: Memphis
# Loser:  Nevada
#
# Winner: Texas A&M
# Loser:  Louisville
#
# Winner: Tennessee
# Loser:  Virginia
#
# Winner: Florida
# Loser:  Butler
#
# Winner: Oregon
# Loser:  UNLV
#
# Winner: Kansas
# Loser:  Southern Illinois
#
# Winner: UCLA
# Loser:  Pittsburgh
#
# Winner: North Carolina
# Loser:  USC
#
# Winner: Georgetown
# Loser:  Vanderbilt
#
# Winner: Ohio St
# Loser:  Tennessee
#
# Winner: Memphis
# Loser:  Texas A&M
#
# Winner: Florida
# Loser:  Oregon
#
# Winner: UCLA
# Loser:  Kansas
#
# Winner: Georgetown
# Loser:  North Carolina
#
# Winner: Ohio St
# Loser:  Memphis
#
# Winner: Florida
# Loser:  UCLA
#
# Winner: Ohio St
# Loser:  Georgetown
#
# Winner: Florida
# Loser:  Ohio St
#
# Winner: North Carolina
# Loser:  Mount St Marys
#
# Winner: Tennessee
# Loser:  American
#
# Winner: Louisville
# Loser:  Boise St
#
# Winner: Washington St
# Loser:  Winthrop
#
# Winner: Notre Dame
# Loser:  George Mason
#
# Winner: Oklahoma
# Loser:  St Josephs
#
# Winner: Butler
# Loser:  South Alabama
#
# Winner: Arkansas
# Loser:  Indiana
#
# Winner: Kansas
# Loser:  Portland St
#
# Winner: Georgetown
# Loser:  UMBC
#
# Winner: Wisconsin
# Loser:  Cal St Fullerton
#
# Winner: Siena
# Loser:  Vanderbilt
#
# Winner: Villanova
# Loser:  Clemson
#
# Winner: Kansas St
# Loser:  USC
#
# Winner: Davidson
# Loser:  Gonzaga
#
# Winner: UNLV
# Loser:  Kent St
#
# Winner: Memphis
# Loser:  Texas Arlington
#
# Winner: Texas
# Loser:  Austin Peay
#
# Winner: Stanford
# Loser:  Cornell
#
# Winner: Pittsburgh
# Loser:  Oral Roberts
#
# Winner: Michigan St
# Loser:  Temple
#
# Winner: Marquette
# Loser:  Kentucky
#
# Winner: Miami
# Loser:  St Marys
#
# Winner: Mississippi St
# Loser:  Oregon
#
# Winner: UCLA
# Loser:  Mississippi Valley St
#
# Winner: Duke
# Loser:  Belmont
#
# Winner: Xavier
# Loser:  Georgia
#
# Winner: San Diego
# Loser:  Connecticut
#
# Winner: Western Kentucky
# Loser:  Drake
#
# Winner: Purdue
# Loser:  Baylor
#
# Winner: West Virginia
# Loser:  Arizona
#
# Winner: Texas A&M
# Loser:  BYU
#
# Winner: North Carolina
# Loser:  Arkansas
#
# Winner: Tennessee
# Loser:  Butler
#
# Winner: Louisville
# Loser:  Oklahoma
#
# Winner: Washington St
# Loser:  Notre Dame
#
# Winner: Kansas
# Loser:  UNLV
#
# Winner: Davidson
# Loser:  Georgetown
#
# Winner: Wisconsin
# Loser:  Kansas St
#
# Winner: Villanova
# Loser:  Siena
#
# Winner: Memphis
# Loser:  Mississippi St
#
# Winner: Texas
# Loser:  Miami
#
# Winner: Stanford
# Loser:  Marquette
#
# Winner: Michigan St
# Loser:  Pittsburgh
#
# Winner: UCLA
# Loser:  Texas A&M
#
# Winner: West Virginia
# Loser:  Duke
#
# Winner: Xavier
# Loser:  Purdue
#
# Winner: Western Kentucky
# Loser:  San Diego
#
# Winner: North Carolina
# Loser:  Washington St
#
# Winner: Louisville
# Loser:  Tennessee
#
# Winner: Kansas
# Loser:  Villanova
#
# Winner: Davidson
# Loser:  Wisconsin
#
# Winner: Memphis
# Loser:  Michigan St
#
# Winner: Texas
# Loser:  Stanford
#
# Winner: UCLA
# Loser:  Western Kentucky
#
# Winner: Xavier
# Loser:  West Virginia
#
# Winner: North Carolina
# Loser:  Louisville
#
# Winner: Kansas
# Loser:  Davidson
#
# Winner: Memphis
# Loser:  Texas
#
# Winner: UCLA
# Loser:  Xavier
#
# Winner: Kansas
# Loser:  North Carolina
#
# Winner: Memphis
# Loser:  UCLA
#
# Winner: Kansas
# Loser:  Memphis
#
# Winner: Louisville
# Loser:  Morehead St
#
# Winner: Michigan St
# Loser:  Robert Morris
#
# Winner: Kansas
# Loser:  North Dakota St
#
# Winner: Cleveland St
# Loser:  Wake Forest
#
# Winner: Arizona
# Loser:  Utah
#
# Winner: Dayton
# Loser:  West Virginia
#
# Winner: USC
# Loser:  Boston College
#
# Winner: Siena
# Loser:  Ohio St
#
# Winner: Connecticut
# Loser:  Chattanooga
#
# Winner: Memphis
# Loser:  Cal St Northridge
#
# Winner: Missouri
# Loser:  Cornell
#
# Winner: Washington
# Loser:  Mississippi St
#
# Winner: Purdue
# Loser:  Northern Iowa
#
# Winner: Marquette
# Loser:  Utah St
#
# Winner: Maryland
# Loser:  California
#
# Winner: Texas A&M
# Loser:  BYU
#
# Winner: Pittsburgh
# Loser:  East Tennessee St
#
# Winner: Duke
# Loser:  Binghamton
#
# Winner: Villanova
# Loser:  American
#
# Winner: Xavier
# Loser:  Portland St
#
# Winner: Wisconsin
# Loser:  Florida St
#
# Winner: UCLA
# Loser:  VCU
#
# Winner: Texas
# Loser:  Minnesota
#
# Winner: Oklahoma St
# Loser:  Tennessee
#
# Winner: North Carolina
# Loser:  Radford
#
# Winner: Oklahoma
# Loser:  Morgan St
#
# Winner: Syracuse
# Loser:  Stephen F Austin
#
# Winner: Gonzaga
# Loser:  Akron
#
# Winner: Western Kentucky
# Loser:  Illinois
#
# Winner: Arizona St
# Loser:  Temple
#
# Winner: Michigan
# Loser:  Clemson
#
# Winner: LSU
# Loser:  Butler
#
# Winner: Louisville
# Loser:  Siena
#
# Winner: Michigan St
# Loser:  USC
#
# Winner: Kansas
# Loser:  Dayton
#
# Winner: Arizona
# Loser:  Cleveland St
#
# Winner: Connecticut
# Loser:  Texas A&M
#
# Winner: Memphis
# Loser:  Maryland
#
# Winner: Missouri
# Loser:  Marquette
#
# Winner: Purdue
# Loser:  Washington
#
# Winner: Pittsburgh
# Loser:  Oklahoma St
#
# Winner: Duke
# Loser:  Texas
#
# Winner: Villanova
# Loser:  UCLA
#
# Winner: Xavier
# Loser:  Wisconsin
#
# Winner: North Carolina
# Loser:  LSU
#
# Winner: Oklahoma
# Loser:  Michigan
#
# Winner: Syracuse
# Loser:  Arizona St
#
# Winner: Gonzaga
# Loser:  Western Kentucky
#
# Winner: Louisville
# Loser:  Arizona
#
# Winner: Michigan St
# Loser:  Kansas
#
# Winner: Connecticut
# Loser:  Purdue
#
# Winner: Missouri
# Loser:  Memphis
#
# Winner: Pittsburgh
# Loser:  Xavier
#
# Winner: Villanova
# Loser:  Duke
#
# Winner: North Carolina
# Loser:  Gonzaga
#
# Winner: Oklahoma
# Loser:  Syracuse
#
# Winner: Michigan St
# Loser:  Louisville
#
# Winner: Connecticut
# Loser:  Missouri
#
# Winner: Villanova
# Loser:  Pittsburgh
#
# Winner: North Carolina
# Loser:  Oklahoma
#
# Winner: Michigan St
# Loser:  Connecticut
#
# Winner: North Carolina
# Loser:  Villanova
#
# Winner: North Carolina
# Loser:  Michigan St
#
# Winner: Kansas
# Loser:  Lehigh
#
# Winner: Ohio St
# Loser:  Santa Barbara
#
# Winner: Ohio
# Loser:  Georgetown
#
# Winner: Maryland
# Loser:  Houston
#
# Winner: Michigan St
# Loser:  New Mexico St
#
# Winner: Tennessee
# Loser:  San Diego St
#
# Winner: Georgia Tech
# Loser:  Oklahoma St
#
# Winner: Northern Iowa
# Loser:  UNLV
#
# Winner: Syracuse
# Loser:  Vermont
#
# Winner: Kansas St
# Loser:  North Texas
#
# Winner: Pittsburgh
# Loser:  Oakland
#
# Winner: Murray St
# Loser:  Vanderbilt
#
# Winner: Butler
# Loser:  UTEP
#
# Winner: Xavier
# Loser:  Minnesota
#
# Winner: BYU
# Loser:  Florida
#
# Winner: Gonzaga
# Loser:  Florida St
#
# Winner: Kentucky
# Loser:  East Tennessee St
#
# Winner: West Virginia
# Loser:  Morgan St
#
# Winner: New Mexico
# Loser:  Montana
#
# Winner: Wisconsin
# Loser:  Wofford
#
# Winner: Cornell
# Loser:  Temple
#
# Winner: Washington
# Loser:  Marquette
#
# Winner: Missouri
# Loser:  Clemson
#
# Winner: Wake Forest
# Loser:  Texas
#
# Winner: Duke
# Loser:  Arkansas Pine Bluff
#
# Winner: Villanova
# Loser:  Robert Morris
#
# Winner: Baylor
# Loser:  Sam Houston St
#
# Winner: Purdue
# Loser:  Siena
#
# Winner: Texas A&M
# Loser:  Utah St
#
# Winner: Old Dominion
# Loser:  Notre Dame
#
# Winner: St Marys
# Loser:  Richmond
#
# Winner: California
# Loser:  Louisville
#
# Winner: Northern Iowa
# Loser:  Kansas
#
# Winner: Ohio St
# Loser:  Georgia Tech
#
# Winner: Tennessee
# Loser:  Ohio
#
# Winner: Michigan St
# Loser:  Maryland
#
# Winner: Syracuse
# Loser:  Gonzaga
#
# Winner: Kansas St
# Loser:  BYU
#
# Winner: Xavier
# Loser:  Pittsburgh
#
# Winner: Butler
# Loser:  Murray St
#
# Winner: Kentucky
# Loser:  Wake Forest
#
# Winner: West Virginia
# Loser:  Missouri
#
# Winner: Washington
# Loser:  New Mexico
#
# Winner: Cornell
# Loser:  Wisconsin
#
# Winner: Duke
# Loser:  California
#
# Winner: St Marys
# Loser:  Villanova
#
# Winner: Baylor
# Loser:  Old Dominion
#
# Winner: Purdue
# Loser:  Texas A&M
#
# Winner: Michigan St
# Loser:  Northern Iowa
#
# Winner: Tennessee
# Loser:  Ohio St
#
# Winner: Butler
# Loser:  Syracuse
#
# Winner: Kansas St
# Loser:  Xavier
#
# Winner: Kentucky
# Loser:  Cornell
#
# Winner: West Virginia
# Loser:  Washington
#
# Winner: Duke
# Loser:  Purdue
#
# Winner: Baylor
# Loser:  St Marys
#
# Winner: Michigan St
# Loser:  Tennessee
#
# Winner: Butler
# Loser:  Kansas St
#
# Winner: West Virginia
# Loser:  Kentucky
#
# Winner: Duke
# Loser:  Baylor
#
# Winner: Butler
# Loser:  Michigan St
#
# Winner: Duke
# Loser:  West Virginia
#
# Winner: Duke
# Loser:  Butler
#
# Winner: Ohio St
# Loser:  Texas San Antonio
#
# Winner: North Carolina
# Loser:  Long Island Brooklyn
#
# Winner: Syracuse
# Loser:  Indiana St
#
# Winner: Kentucky
# Loser:  Princeton
#
# Winner: West Virginia
# Loser:  Clemson
#
# Winner: Marquette
# Loser:  Xavier
#
# Winner: Washington
# Loser:  Georgia
#
# Winner: George Mason
# Loser:  Villanova
#
# Winner: Duke
# Loser:  Hampton
#
# Winner: San Diego St
# Loser:  Northern Colorado
#
# Winner: Connecticut
# Loser:  Bucknell
#
# Winner: Texas
# Loser:  Oakland
#
# Winner: Arizona
# Loser:  Memphis
#
# Winner: Cincinnati
# Loser:  Missouri
#
# Winner: Temple
# Loser:  Penn St
#
# Winner: Michigan
# Loser:  Tennessee
#
# Winner: Kansas
# Loser:  Boston University
#
# Winner: Notre Dame
# Loser:  Akron
#
# Winner: Purdue
# Loser:  St Peters
#
# Winner: Morehead St
# Loser:  Louisville
#
# Winner: Richmond
# Loser:  Vanderbilt
#
# Winner: VCU
# Loser:  Georgetown
#
# Winner: Florida St
# Loser:  Texas A&M
#
# Winner: Illinois
# Loser:  UNLV
#
# Winner: Pittsburgh
# Loser:  UNC Asheville
#
# Winner: Florida
# Loser:  Santa Barbara
#
# Winner: BYU
# Loser:  Wofford
#
# Winner: Wisconsin
# Loser:  Belmont
#
# Winner: Kansas St
# Loser:  Utah St
#
# Winner: Gonzaga
# Loser:  St Johns
#
# Winner: UCLA
# Loser:  Michigan St
#
# Winner: Butler
# Loser:  Old Dominion
#
# Winner: Ohio St
# Loser:  George Mason
#
# Winner: North Carolina
# Loser:  Washington
#
# Winner: Marquette
# Loser:  Syracuse
#
# Winner: Kentucky
# Loser:  West Virginia
#
# Winner: Duke
# Loser:  Michigan
#
# Winner: San Diego St
# Loser:  Temple
#
# Winner: Connecticut
# Loser:  Cincinnati
#
# Winner: Arizona
# Loser:  Texas
#
# Winner: Kansas
# Loser:  Illinois
#
# Winner: Florida St
# Loser:  Notre Dame
#
# Winner: VCU
# Loser:  Purdue
#
# Winner: Richmond
# Loser:  Morehead St
#
# Winner: Butler
# Loser:  Pittsburgh
#
# Winner: Florida
# Loser:  UCLA
#
# Winner: BYU
# Loser:  Gonzaga
#
# Winner: Wisconsin
# Loser:  Kansas St
#
# Winner: Kentucky
# Loser:  Ohio St
#
# Winner: North Carolina
# Loser:  Marquette
#
# Winner: Arizona
# Loser:  Duke
#
# Winner: Connecticut
# Loser:  San Diego St
#
# Winner: Kansas
# Loser:  Richmond
#
# Winner: VCU
# Loser:  Florida St
#
# Winner: Butler
# Loser:  Wisconsin
#
# Winner: Florida
# Loser:  BYU
#
# Winner: Kentucky
# Loser:  North Carolina
#
# Winner: Connecticut
# Loser:  Arizona
#
# Winner: VCU
# Loser:  Kansas
#
# Winner: Butler
# Loser:  Florida
#
# Winner: Connecticut
# Loser:  Kentucky
#
# Winner: Butler
# Loser:  VCU
#
# Winner: Connecticut
# Loser:  Butler
#
# Winner: Kentucky
# Loser:  Western Kentucky
#
# Winner: Lehigh
# Loser:  Duke
#
# Winner: Baylor
# Loser:  South Dakota St
#
# Winner: Indiana
# Loser:  New Mexico St
#
# Winner: VCU
# Loser:  Wichita St
#
# Winner: Colorado
# Loser:  UNLV
#
# Winner: Xavier
# Loser:  Notre Dame
#
# Winner: Iowa St
# Loser:  Connecticut
#
# Winner: Michigan St
# Loser:  Long Island Brooklyn
#
# Winner: Norfolk St
# Loser:  Missouri
#
# Winner: Marquette
# Loser:  BYU
#
# Winner: Louisville
# Loser:  Davidson
#
# Winner: New Mexico
# Loser:  Long Beach St
#
# Winner: Murray St
# Loser:  Colorado St
#
# Winner: Florida
# Loser:  Virginia
#
# Winner: St Louis
# Loser:  Memphis
#
# Winner: Syracuse
# Loser:  UNC Asheville
#
# Winner: Ohio St
# Loser:  Loyola Maryland
#
# Winner: Florida St
# Loser:  St Bonaventure
#
# Winner: Wisconsin
# Loser:  Montana
#
# Winner: Vanderbilt
# Loser:  Harvard
#
# Winner: Cincinnati
# Loser:  Texas
#
# Winner: Gonzaga
# Loser:  West Virginia
#
# Winner: Kansas St
# Loser:  Southern Mississippi
#
# Winner: North Carolina
# Loser:  Vermont
#
# Winner: Kansas
# Loser:  Detroit
#
# Winner: Georgetown
# Loser:  Belmont
#
# Winner: Ohio
# Loser:  Michigan
#
# Winner: South Florida
# Loser:  Temple
#
# Winner: NC State
# Loser:  San Diego St
#
# Winner: Purdue
# Loser:  St Marys
#
# Winner: Creighton
# Loser:  Alabama
#
# Winner: Kentucky
# Loser:  Iowa St
#
# Winner: Xavier
# Loser:  Lehigh
#
# Winner: Baylor
# Loser:  Colorado
#
# Winner: Indiana
# Loser:  VCU
#
# Winner: Michigan St
# Loser:  St Louis
#
# Winner: Florida
# Loser:  Norfolk St
#
# Winner: Marquette
# Loser:  Murray St
#
# Winner: Louisville
# Loser:  New Mexico
#
# Winner: Syracuse
# Loser:  Kansas St
#
# Winner: Ohio St
# Loser:  Gonzaga
#
# Winner: Cincinnati
# Loser:  Florida St
#
# Winner: Wisconsin
# Loser:  Vanderbilt
#
# Winner: North Carolina
# Loser:  Creighton
#
# Winner: Kansas
# Loser:  Purdue
#
# Winner: NC State
# Loser:  Georgetown
#
# Winner: Ohio
# Loser:  South Florida
#
# Winner: Kentucky
# Loser:  Indiana
#
# Winner: Baylor
# Loser:  Xavier
#
# Winner: Louisville
# Loser:  Michigan St
#
# Winner: Florida
# Loser:  Marquette
#
# Winner: Syracuse
# Loser:  Wisconsin
#
# Winner: Ohio St
# Loser:  Cincinnati
#
# Winner: North Carolina
# Loser:  Ohio
#
# Winner: Kansas
# Loser:  NC State
#
# Winner: Kentucky
# Loser:  Baylor
#
# Winner: Louisville
# Loser:  Florida
#
# Winner: Ohio St
# Loser:  Syracuse
#
# Winner: Kansas
# Loser:  North Carolina
#
# Winner: Kentucky
# Loser:  Louisville
#
# Winner: Kansas
# Loser:  Ohio St
#
# Winner: Kentucky
# Loser:  Kansas
#
# Winner: Louisville
# Loser:  North Carolina A&T
#
# Winner: Duke
# Loser:  Albany
#
# Winner: Michigan St
# Loser:  Valparaiso
#
# Winner: St Louis
# Loser:  New Mexico St
#
# Winner: Oregon
# Loser:  Oklahoma St
#
# Winner: Memphis
# Loser:  St Marys
#
# Winner: Creighton
# Loser:  Cincinnati
#
# Winner: Colorado St
# Loser:  Missouri
#
# Winner: Gonzaga
# Loser:  Southern
#
# Winner: Ohio St
# Loser:  Iona
#
# Winner: Harvard
# Loser:  New Mexico
#
# Winner: La Salle
# Loser:  Kansas St
#
# Winner: Ole Miss
# Loser:  Wisconsin
#
# Winner: Arizona
# Loser:  Belmont
#
# Winner: Iowa St
# Loser:  Notre Dame
#
# Winner: Wichita St
# Loser:  Pittsburgh
#
# Winner: Kansas
# Loser:  Western Kentucky
#
# Winner: Florida Gulf Coast
# Loser:  Georgetown
#
# Winner: Florida
# Loser:  Northwestern St
#
# Winner: Michigan
# Loser:  South Dakota St
#
# Winner: VCU
# Loser:  Akron
#
# Winner: Minnesota
# Loser:  UCLA
#
# Winner: San Diego St
# Loser:  Oklahoma
#
# Winner: North Carolina
# Loser:  Villanova
#
# Winner: Indiana
# Loser:  James Madison
#
# Winner: Miami
# Loser:  Pacific
#
# Winner: Marquette
# Loser:  Davidson
#
# Winner: Syracuse
# Loser:  Montana
#
# Winner: California
# Loser:  UNLV
#
# Winner: Butler
# Loser:  Bucknell
#
# Winner: Illinois
# Loser:  Colorado
#
# Winner: Temple
# Loser:  NC State
#
# Winner: Louisville
# Loser:  Colorado St
#
# Winner: Duke
# Loser:  Creighton
#
# Winner: Michigan St
# Loser:  Memphis
#
# Winner: Oregon
# Loser:  St Louis
#
# Winner: Wichita St
# Loser:  Gonzaga
#
# Winner: Ohio St
# Loser:  Iowa St
#
# Winner: Arizona
# Loser:  Harvard
#
# Winner: La Salle
# Loser:  Ole Miss
#
# Winner: Kansas
# Loser:  North Carolina
#
# Winner: Florida Gulf Coast
# Loser:  San Diego St
#
# Winner: Florida
# Loser:  Minnesota
#
# Winner: Michigan
# Loser:  VCU
#
# Winner: Indiana
# Loser:  Temple
#
# Winner: Miami
# Loser:  Illinois
#
# Winner: Marquette
# Loser:  Butler
#
# Winner: Syracuse
# Loser:  California
#
# Winner: Louisville
# Loser:  Oregon
#
# Winner: Duke
# Loser:  Michigan St
#
# Winner: Wichita St
# Loser:  La Salle
#
# Winner: Ohio St
# Loser:  Arizona
#
# Winner: Michigan
# Loser:  Kansas
#
# Winner: Florida
# Loser:  Florida Gulf Coast
#
# Winner: Syracuse
# Loser:  Indiana
#
# Winner: Marquette
# Loser:  Miami
#
# Winner: Louisville
# Loser:  Duke
#
# Winner: Wichita St
# Loser:  Ohio St
#
# Winner: Michigan
# Loser:  Florida
#
# Winner: Syracuse
# Loser:  Marquette
#
# Winner: Louisville
# Loser:  Wichita St
#
# Winner: Michigan
# Loser:  Syracuse
#
# Winner: Louisville
# Loser:  Michigan
#
# Winner: Florida
# Loser:  Albany
#
# Winner: Kansas
# Loser:  Eastern Kentucky
#
# Winner: Syracuse
# Loser:  Western Michigan
#
# Winner: UCLA
# Loser:  Tulsa
#
# Winner: Stephen F Austin
# Loser:  VCU
#
# Winner: Dayton
# Loser:  Ohio St
#
# Winner: Stanford
# Loser:  New Mexico
#
# Winner: Pittsburgh
# Loser:  Colorado
#
# Winner: Virginia
# Loser:  Coastal Carolina
#
# Winner: Villanova
# Loser:  Wisconsin Milwaukee
#
# Winner: Iowa St
# Loser:  North Carolina Central
#
# Winner: Michigan St
# Loser:  Delaware
#
# Winner: Harvard
# Loser:  Cincinnati
#
# Winner: North Carolina
# Loser:  Providence
#
# Winner: Connecticut
# Loser:  St Josephs
#
# Winner: Memphis
# Loser:  George Washington
#
# Winner: Arizona
# Loser:  Weber St
#
# Winner: Wisconsin
# Loser:  American
#
# Winner: Creighton
# Loser:  Louisiana Lafayette
#
# Winner: San Diego St
# Loser:  New Mexico St
#
# Winner: North Dakota St
# Loser:  Oklahoma
#
# Winner: Baylor
# Loser:  Nebraska
#
# Winner: Oregon
# Loser:  BYU
#
# Winner: Gonzaga
# Loser:  Oklahoma St
#
# Winner: Wichita St
# Loser:  Cal Poly
#
# Winner: Michigan
# Loser:  Wofford
#
# Winner: Mercer
# Loser:  Duke
#
# Winner: Louisville
# Loser:  Manhattan
#
# Winner: St Louis
# Loser:  NC State
#
# Winner: Tennessee
# Loser:  Massachusetts
#
# Winner: Texas
# Loser:  Arizona St
#
# Winner: Kentucky
# Loser:  Kansas St
#
# Winner: Florida
# Loser:  Pittsburgh
#
# Winner: Stanford
# Loser:  Kansas
#
# Winner: Dayton
# Loser:  Syracuse
#
# Winner: UCLA
# Loser:  Stephen F Austin
#
# Winner: Virginia
# Loser:  Memphis
#
# Winner: Connecticut
# Loser:  Villanova
#
# Winner: Iowa St
# Loser:  North Carolina
#
# Winner: Michigan St
# Loser:  Harvard
#
# Winner: Arizona
# Loser:  Gonzaga
#
# Winner: Wisconsin
# Loser:  Oregon
#
# Winner: Baylor
# Loser:  Creighton
#
# Winner: San Diego St
# Loser:  North Dakota St
#
# Winner: Kentucky
# Loser:  Wichita St
#
# Winner: Michigan
# Loser:  Texas
#
# Winner: Tennessee
# Loser:  Mercer
#
# Winner: Louisville
# Loser:  St Louis
#
# Winner: Florida
# Loser:  UCLA
#
# Winner: Dayton
# Loser:  Stanford
#
# Winner: Michigan St
# Loser:  Virginia
#
# Winner: Connecticut
# Loser:  Iowa St
#
# Winner: Arizona
# Loser:  San Diego St
#
# Winner: Wisconsin
# Loser:  Baylor
#
# Winner: Kentucky
# Loser:  Louisville
#
# Winner: Michigan
# Loser:  Tennessee
#
# Winner: Florida
# Loser:  Dayton
#
# Winner: Connecticut
# Loser:  Michigan St
#
# Winner: Wisconsin
# Loser:  Arizona
#
# Winner: Kentucky
# Loser:  Michigan
#
# Winner: Connecticut
# Loser:  Florida
#
# Winner: Kentucky
# Loser:  Wisconsin
#
# Winner: Connecticut
# Loser:  Kentucky
#
# Winner: Kentucky
# Loser:  Hampton
#
# Winner: Kansas
# Loser:  New Mexico St
#
# Winner: Notre Dame
# Loser:  Northeastern
#
# Winner: Maryland
# Loser:  Valparaiso
#
# Winner: West Virginia
# Loser:  Buffalo
#
# Winner: Butler
# Loser:  Texas
#
# Winner: Wichita St
# Loser:  Indiana
#
# Winner: Cincinnati
# Loser:  Purdue
#
# Winner: Wisconsin
# Loser:  Coastal Carolina
#
# Winner: Arizona
# Loser:  Texas Southern
#
# Winner: Georgia St
# Loser:  Baylor
#
# Winner: North Carolina
# Loser:  Harvard
#
# Winner: Arkansas
# Loser:  Wofford
#
# Winner: Xavier
# Loser:  Ole Miss
#
# Winner: Ohio St
# Loser:  VCU
#
# Winner: Oregon
# Loser:  Oklahoma St
#
# Winner: Villanova
# Loser:  Lafayette
#
# Winner: Virginia
# Loser:  Belmont
#
# Winner: Oklahoma
# Loser:  Albany
#
# Winner: Louisville
# Loser:  Cal Irvine
#
# Winner: Northern Iowa
# Loser:  Wyoming
#
# Winner: Dayton
# Loser:  Providence
#
# Winner: Michigan St
# Loser:  Georgia
#
# Winner: NC State
# Loser:  LSU
#
# Winner: Duke
# Loser:  Robert Morris
#
# Winner: Gonzaga
# Loser:  North Dakota St
#
# Winner: UAB
# Loser:  Iowa St
#
# Winner: Georgetown
# Loser:  Eastern Washington
#
# Winner: Utah
# Loser:  Stephen F Austin
#
# Winner: UCLA
# Loser:  SMU
#
# Winner: Iowa
# Loser:  Davidson
#
# Winner: San Diego St
# Loser:  St Johns
#
# Winner: Kentucky
# Loser:  Cincinnati
#
# Winner: Wichita St
# Loser:  Kansas
#
# Winner: Notre Dame
# Loser:  Butler
#
# Winner: West Virginia
# Loser:  Maryland
#
# Winner: Wisconsin
# Loser:  Oregon
#
# Winner: Arizona
# Loser:  Ohio St
#
# Winner: Xavier
# Loser:  Georgia St
#
# Winner: North Carolina
# Loser:  Arkansas
#
# Winner: NC State
# Loser:  Villanova
#
# Winner: Michigan St
# Loser:  Virginia
#
# Winner: Oklahoma
# Loser:  Dayton
#
# Winner: Louisville
# Loser:  Northern Iowa
#
# Winner: Duke
# Loser:  San Diego St
#
# Winner: Gonzaga
# Loser:  Iowa
#
# Winner: UCLA
# Loser:  UAB
#
# Winner: Utah
# Loser:  Georgetown
#
# Winner: Kentucky
# Loser:  West Virginia
#
# Winner: Notre Dame
# Loser:  Wichita St
#
# Winner: Wisconsin
# Loser:  North Carolina
#
# Winner: Arizona
# Loser:  Xavier
#
# Winner: Louisville
# Loser:  NC State
#
# Winner: Michigan St
# Loser:  Oklahoma
#
# Winner: Duke
# Loser:  Utah
#
# Winner: Gonzaga
# Loser:  UCLA
#
# Winner: Kentucky
# Loser:  Notre Dame
#
# Winner: Wisconsin
# Loser:  Arizona
#
# Winner: Michigan St
# Loser:  Louisville
#
# Winner: Duke
# Loser:  Gonzaga
#
# Winner: Wisconsin
# Loser:  Kentucky
#
# Winner: Duke
# Loser:  Michigan St
#
# Winner: Duke
# Loser:  Wisconsin

# %%
# Move testing data into 2 numpy arrays - data and labels (results)
N = len(res_data_test)

testing_data = np.zeros((N,13))
testing_labels = np.zeros((N,1))

for i in range(len(res_data_test)):
#for i in range(5):
    year = res_data_test['Year'][i]
    teamA = res_data_test['TeamA'][i]
    teamB = res_data_test['TeamB'][i]
    score_diff = res_data_test['ScoreA'][i] - res_data_test['ScoreB'][i]
    for k in range(len(stats_data_test)):
        if ((stats_data_test['Season'][k] == year) and (stats_data_test['TeamName'][k] == teamA)):
            indexA = k
            break
            
    for k in range(len(stats_data_test)):
        if ((stats_data_test['Season'][k] == year) and (stats_data_test['TeamName'][k] == teamB)):
            indexB = k
            break
    for s in range(len(stats_vec)):
        stat = stats_vec[s]
        testing_data[i][s] = stats_data_test[stat][indexA] - stats_data_test[stat][indexB]
    
    if (score_diff > 0):
        testing_labels[i][0] = 1
    else:
        testing_labels[i][0] = 0

# %%
print(training_data.shape)
print(training_labels.shape)
print('\n')
print(testing_data.shape)
print(testing_labels.shape)
# Out:
# (882, 13)
# (882, 1)
#
#
# (189, 13)
# (189, 1)

# %%
#Time to normalize the data
training_data = preprocessing.normalize(training_data, axis=0, norm='max')
testing_data = preprocessing.normalize(testing_data, axis=0, norm='max')

# %%
dtrain = xgb.DMatrix(training_data, label=training_labels,
                     feature_names=stats_vec)
dtest = xgb.DMatrix(testing_data, label=testing_labels,
                    feature_names=stats_vec)

# %%
#Phase 1: Tuning Max depth and min_child_weight
param = {'objective': 'multi:softprob'}
param['eval_metric'] = "merror"
param['num_class'] = 2  # 2 classes - win or loss

#evallist = [(dtest, 'eval'), (dtrain, 'train')]

num_round = 999 #looks like it levels off at around 200

gridsearch_params = [
    (max_depth, min_child_weight)
    for max_depth in range(1,8)
    for min_child_weight in range(1,6)
]
min_merror = float("Inf")
best_params = None
for max_depth, min_child_weight in gridsearch_params:
    print("CV with max_depth={}, min_child_weight={}".format(
                             max_depth,
                             min_child_weight))
    
    # Update Parameters
    param['max_depth'] = max_depth
    param['min_child_weight'] = min_child_weight
    
    #Run CV
    cv_results = xgb.cv(param,
                        dtrain,
                        num_boost_round=num_round, #maybe wrong
                        seed=42,
                        nfold=3,
                        metrics={'merror'},
                        early_stopping_rounds=10)
    
    #Update best MError
    mean_merror = cv_results['test-merror-mean'].min()
    boost_rounds = cv_results['test-merror-mean'].argmin()
    print("\tMerror {} for {} rounds".format(mean_merror, boost_rounds))
    if mean_merror < min_merror:
        min_merror = mean_merror
        best_params = (max_depth, min_child_weight)
    

param['max_depth'] = best_params[0]
param['min_child_weight'] = best_params[1]
# Out:
# CV with max_depth=1, min_child_weight=1
# 	Merror 0.2834466666666667 for 0 rounds
# CV with max_depth=1, min_child_weight=2
# 	Merror 0.2834466666666667 for 0 rounds
# CV with max_depth=1, min_child_weight=3
# 	Merror 0.2834466666666667 for 0 rounds
# CV with max_depth=1, min_child_weight=4
# 	Merror 0.2834466666666667 for 0 rounds
# CV with max_depth=1, min_child_weight=5
# 	Merror 0.2834466666666667 for 0 rounds
# CV with max_depth=2, min_child_weight=1
# 	Merror 0.27210866666666667 for 23 rounds
# CV with max_depth=2, min_child_weight=2
# 	Merror 0.2732426666666667 for 20 rounds
# CV with max_depth=2, min_child_weight=3
# 	Merror 0.26870733333333335 for 14 rounds
# CV with max_depth=2, min_child_weight=4
# 	Merror 0.26757366666666665 for 18 rounds
# CV with max_depth=2, min_child_weight=5
# 	Merror 0.2732426666666667 for 5 rounds
# CV with max_depth=3, min_child_weight=1
# 	Merror 0.27097533333333335 for 2 rounds
# CV with max_depth=3, min_child_weight=2
# 	Merror 0.26870733333333335 for 2 rounds
# CV with max_depth=3, min_child_weight=3
# 	Merror 0.2698413333333333 for 2 rounds
# CV with max_depth=3, min_child_weight=4
# 	Merror 0.2687076666666666 for 2 rounds
# CV with max_depth=3, min_child_weight=5
# 	Merror 0.27664399999999995 for 2 rounds
# CV with max_depth=4, min_child_weight=1
# 	Merror 0.282313 for 2 rounds
# CV with max_depth=4, min_child_weight=2
# 	Merror 0.285714 for 4 rounds
# CV with max_depth=4, min_child_weight=3
# 	Merror 0.29251699999999997 for 4 rounds
# CV with max_depth=4, min_child_weight=4
# 	Merror 0.285714 for 7 rounds
# CV with max_depth=4, min_child_weight=5
# 	Merror 0.283447 for 11 rounds
# CV with max_depth=5, min_child_weight=1
# 	Merror 0.2868483333333333 for 5 rounds
# CV with max_depth=5, min_child_weight=2
# 	Merror 0.28571399999999997 for 26 rounds
# CV with max_depth=5, min_child_weight=3
# 	Merror 0.281179 for 6 rounds
# CV with max_depth=5, min_child_weight=4
# 	Merror 0.29024933333333336 for 9 rounds
# CV with max_depth=5, min_child_weight=5
# 	Merror 0.28458066666666665 for 11 rounds
# CV with max_depth=6, min_child_weight=1
# 	Merror 0.2834466666666667 for 19 rounds
# CV with max_depth=6, min_child_weight=2
# 	Merror 0.281179 for 10 rounds
# CV with max_depth=6, min_child_weight=3
# 	Merror 0.2732426666666667 for 6 rounds
# CV with max_depth=6, min_child_weight=4
# 	Merror 0.28911566666666666 for 23 rounds
# CV with max_depth=6, min_child_weight=5
# 	Merror 0.27664399999999995 for 4 rounds
# CV with max_depth=7, min_child_weight=1
# 	Merror 0.2913833333333333 for 13 rounds
# CV with max_depth=7, min_child_weight=2
# 	Merror 0.2834466666666667 for 6 rounds
# CV with max_depth=7, min_child_weight=3
# 	Merror 0.2845803333333334 for 6 rounds
# CV with max_depth=7, min_child_weight=4
# 	Merror 0.2811793333333334 for 8 rounds
# CV with max_depth=7, min_child_weight=5
# 	Merror 0.28571433333333335 for 7 rounds

# %%
#Phase 2: Subsample and Colsample_bytree
#tune subsample,colsample
gridsearch_params = [
    (subsample, colsample)
    for subsample in [i/10. for i in range(1,11)]
    for colsample in [i/10. for i in range(1,11)]
]
min_merror = float("Inf")
best_params = None
for subsample, colsample in reversed(gridsearch_params):
    print("CV with subsample={}, colsample={}".format(
                             subsample,
                             colsample))
    # Update our parameters
    param['subsample'] = subsample
    param['colsample_bytree'] = colsample
    # Run CV
    cv_results = xgb.cv(
        param,
        dtrain,
        num_boost_round=num_round,
        seed=42,
        nfold=3,
        metrics={'merror'},
        early_stopping_rounds=10
    )
    # Update best Merror
    mean_merror = cv_results['test-merror-mean'].min()
    boost_rounds = cv_results['test-merror-mean'].argmin()
    print("\tMerror {} for {} rounds".format(mean_merror, boost_rounds))
    if mean_merror < min_merror:
        min_merror = mean_merror
        best_params = (subsample,colsample)
        
        
param['subsample'] = best_params[0]
param['colsample_bytree'] = best_params[1]
# Out:
# CV with subsample=1.0, colsample=1.0
# 	Merror 0.26757366666666665 for 18 rounds
# CV with subsample=1.0, colsample=0.9
# 	Merror 0.269841 for 16 rounds
# CV with subsample=1.0, colsample=0.8
# 	Merror 0.2619046666666667 for 22 rounds
# CV with subsample=1.0, colsample=0.7
# 	Merror 0.2721086666666666 for 19 rounds
# CV with subsample=1.0, colsample=0.6
# 	Merror 0.27437633333333333 for 6 rounds
# CV with subsample=1.0, colsample=0.5
# 	Merror 0.2743766666666667 for 1 rounds
# CV with subsample=1.0, colsample=0.4
# 	Merror 0.27437633333333333 for 12 rounds
# CV with subsample=1.0, colsample=0.3
# 	Merror 0.2766436666666667 for 6 rounds
# CV with subsample=1.0, colsample=0.2
# 	Merror 0.281179 for 1 rounds
# CV with subsample=1.0, colsample=0.1
# 	Merror 0.28231300000000004 for 7 rounds
# CV with subsample=0.9, colsample=1.0
# 	Merror 0.27324233333333336 for 1 rounds
# CV with subsample=0.9, colsample=0.9
# 	Merror 0.270975 for 10 rounds
# CV with subsample=0.9, colsample=0.8
# 	Merror 0.25963733333333333 for 16 rounds
# CV with subsample=0.9, colsample=0.7
# 	Merror 0.2732426666666667 for 8 rounds
# CV with subsample=0.9, colsample=0.6
# 	Merror 0.27210866666666667 for 12 rounds
# CV with subsample=0.9, colsample=0.5
# 	Merror 0.27097499999999997 for 13 rounds
# CV with subsample=0.9, colsample=0.4
# 	Merror 0.277778 for 6 rounds
# CV with subsample=0.9, colsample=0.3
# 	Merror 0.2800453333333333 for 6 rounds
# CV with subsample=0.9, colsample=0.2
# 	Merror 0.282313 for 0 rounds
# CV with subsample=0.9, colsample=0.1
# 	Merror 0.282313 for 7 rounds
# CV with subsample=0.8, colsample=1.0
# 	Merror 0.26643966666666663 for 13 rounds
# CV with subsample=0.8, colsample=0.9
# 	Merror 0.26870733333333335 for 10 rounds
# CV with subsample=0.8, colsample=0.8
# 	Merror 0.2800453333333333 for 20 rounds
# CV with subsample=0.8, colsample=0.7
# 	Merror 0.28231266666666666 for 16 rounds
# CV with subsample=0.8, colsample=0.6
# 	Merror 0.27097499999999997 for 13 rounds
# CV with subsample=0.8, colsample=0.5
# 	Merror 0.2811793333333333 for 1 rounds
# CV with subsample=0.8, colsample=0.4
# 	Merror 0.27777766666666664 for 3 rounds
# CV with subsample=0.8, colsample=0.3
# 	Merror 0.2800453333333333 for 5 rounds
# CV with subsample=0.8, colsample=0.2
# 	Merror 0.2834466666666667 for 0 rounds
# CV with subsample=0.8, colsample=0.1
# 	Merror 0.282313 for 3 rounds
# CV with subsample=0.7, colsample=1.0
# 	Merror 0.28684766666666667 for 2 rounds
# CV with subsample=0.7, colsample=0.9
# 	Merror 0.255102 for 5 rounds
# CV with subsample=0.7, colsample=0.8
# 	Merror 0.26303866666666664 for 7 rounds
# CV with subsample=0.7, colsample=0.7
# 	Merror 0.2721086666666666 for 7 rounds
# CV with subsample=0.7, colsample=0.6
# 	Merror 0.27097499999999997 for 9 rounds
# CV with subsample=0.7, colsample=0.5
# 	Merror 0.2800453333333333 for 7 rounds
# CV with subsample=0.7, colsample=0.4
# 	Merror 0.27891166666666667 for 1 rounds
# CV with subsample=0.7, colsample=0.3
# 	Merror 0.27437666666666666 for 8 rounds
# CV with subsample=0.7, colsample=0.2
# 	Merror 0.27777766666666664 for 11 rounds
# CV with subsample=0.7, colsample=0.1
# 	Merror 0.2811793333333333 for 3 rounds
# CV with subsample=0.6, colsample=1.0
# 	Merror 0.27324299999999996 for 8 rounds
# CV with subsample=0.6, colsample=0.9
# 	Merror 0.258503 for 5 rounds
# CV with subsample=0.6, colsample=0.8
# 	Merror 0.258503 for 5 rounds
# CV with subsample=0.6, colsample=0.7
# 	Merror 0.2641723333333334 for 6 rounds
# CV with subsample=0.6, colsample=0.6
# 	Merror 0.26077100000000003 for 5 rounds
# CV with subsample=0.6, colsample=0.5
# 	Merror 0.26870733333333335 for 1 rounds
# CV with subsample=0.6, colsample=0.4
# 	Merror 0.27777766666666664 for 9 rounds
# CV with subsample=0.6, colsample=0.3
# 	Merror 0.27664399999999995 for 7 rounds
# CV with subsample=0.6, colsample=0.2
# 	Merror 0.2755103333333333 for 9 rounds
# CV with subsample=0.6, colsample=0.1
# 	Merror 0.282313 for 2 rounds
# CV with subsample=0.5, colsample=1.0
# 	Merror 0.2562356666666667 for 25 rounds
# CV with subsample=0.5, colsample=0.9
# 	Merror 0.2562356666666667 for 25 rounds
# CV with subsample=0.5, colsample=0.8
# 	Merror 0.2619046666666667 for 24 rounds
# CV with subsample=0.5, colsample=0.7
# 	Merror 0.264172 for 11 rounds
# CV with subsample=0.5, colsample=0.6
# 	Merror 0.2721086666666666 for 25 rounds
# CV with subsample=0.5, colsample=0.5
# 	Merror 0.27097499999999997 for 9 rounds
# CV with subsample=0.5, colsample=0.4
# 	Merror 0.2766436666666667 for 6 rounds
# CV with subsample=0.5, colsample=0.3
# 	Merror 0.276644 for 6 rounds
# CV with subsample=0.5, colsample=0.2
# 	Merror 0.277778 for 6 rounds
# CV with subsample=0.5, colsample=0.1
# 	Merror 0.2811793333333334 for 9 rounds
# CV with subsample=0.4, colsample=1.0
# 	Merror 0.265306 for 14 rounds
# CV with subsample=0.4, colsample=0.9
# 	Merror 0.264172 for 11 rounds
# CV with subsample=0.4, colsample=0.8
# 	Merror 0.25963699999999995 for 11 rounds
# CV with subsample=0.4, colsample=0.7
# 	Merror 0.2630383333333333 for 8 rounds
# CV with subsample=0.4, colsample=0.6
# 	Merror 0.2721086666666666 for 0 rounds
# CV with subsample=0.4, colsample=0.5
# 	Merror 0.27097466666666664 for 0 rounds
# CV with subsample=0.4, colsample=0.4
# 	Merror 0.28231266666666666 for 3 rounds
# CV with subsample=0.4, colsample=0.3
# 	Merror 0.2732426666666667 for 14 rounds
# CV with subsample=0.4, colsample=0.2
# 	Merror 0.281179 for 4 rounds
# CV with subsample=0.4, colsample=0.1
# 	Merror 0.28231266666666666 for 14 rounds
# CV with subsample=0.3, colsample=1.0
# 	Merror 0.26077100000000003 for 0 rounds
# CV with subsample=0.3, colsample=0.9
# 	Merror 0.26757366666666665 for 4 rounds
# CV with subsample=0.3, colsample=0.8
# 	Merror 0.25963699999999995 for 5 rounds
# CV with subsample=0.3, colsample=0.7
# 	Merror 0.2641723333333334 for 9 rounds
# CV with subsample=0.3, colsample=0.6
# 	Merror 0.265306 for 8 rounds
# CV with subsample=0.3, colsample=0.5
# 	Merror 0.2732426666666667 for 6 rounds
# CV with subsample=0.3, colsample=0.4
# 	Merror 0.27551 for 8 rounds
# CV with subsample=0.3, colsample=0.3
# 	Merror 0.27891166666666667 for 6 rounds
# CV with subsample=0.3, colsample=0.2
# 	Merror 0.28004566666666664 for 5 rounds
# CV with subsample=0.3, colsample=0.1
# 	Merror 0.27891166666666667 for 10 rounds
# CV with subsample=0.2, colsample=1.0
# 	Merror 0.27097499999999997 for 14 rounds
# CV with subsample=0.2, colsample=0.9
# 	Merror 0.2732426666666667 for 8 rounds
# CV with subsample=0.2, colsample=0.8
# 	Merror 0.2732426666666667 for 8 rounds
# CV with subsample=0.2, colsample=0.7
# 	Merror 0.2732426666666667 for 8 rounds
# CV with subsample=0.2, colsample=0.6
# 	Merror 0.2687076666666666 for 7 rounds
# CV with subsample=0.2, colsample=0.5
# 	Merror 0.2698413333333333 for 8 rounds
# CV with subsample=0.2, colsample=0.4
# 	Merror 0.26870733333333335 for 9 rounds
# CV with subsample=0.2, colsample=0.3
# 	Merror 0.2687076666666666 for 10 rounds
# CV with subsample=0.2, colsample=0.2
# 	Merror 0.2732426666666667 for 4 rounds
# CV with subsample=0.2, colsample=0.1
# 	Merror 0.27551033333333336 for 9 rounds
# CV with subsample=0.1, colsample=1.0
# 	Merror 0.27551 for 12 rounds
# CV with subsample=0.1, colsample=0.9
# 	Merror 0.2766436666666667 for 21 rounds
# CV with subsample=0.1, colsample=0.8
# 	Merror 0.2641723333333333 for 22 rounds
# CV with subsample=0.1, colsample=0.7
# 	Merror 0.27097499999999997 for 22 rounds
# CV with subsample=0.1, colsample=0.6
# 	Merror 0.2755103333333333 for 19 rounds
# CV with subsample=0.1, colsample=0.5
# 	Merror 0.26757366666666665 for 29 rounds
# CV with subsample=0.1, colsample=0.4
# 	Merror 0.29251699999999997 for 16 rounds
# CV with subsample=0.1, colsample=0.3
# 	Merror 0.28231300000000004 for 3 rounds
# CV with subsample=0.1, colsample=0.2
# 	Merror 0.282313 for 6 rounds
# CV with subsample=0.1, colsample=0.1
# 	Merror 0.27437633333333333 for 6 rounds

# %%
#Phase 3: eta
min_merror = float("Inf")
best_params = None
for eta in [0.5,0.3, 0.03, .003,0.0003]:
    print("CV with eta={}".format(eta))
    # Update our parameters
    param['eta'] = eta
    # Run CV
    cv_results = xgb.cv(
        param,
        dtrain,
        num_boost_round=num_round,
        seed=42,
        nfold=3,
        metrics={'merror'},
        early_stopping_rounds=10
    )
    # Update best Merror
    mean_merror = cv_results['test-merror-mean'].min()
    boost_rounds = cv_results['test-merror-mean'].argmin()
    print("\tMerror {} for {} rounds".format(mean_merror, boost_rounds))
    if mean_merror < min_merror:
        min_merror = mean_merror
        best_params = eta
        
param['eta'] = best_params
# Out:
# CV with eta=0.5
# 	Merror 0.2619046666666667 for 8 rounds
# CV with eta=0.3
# 	Merror 0.255102 for 5 rounds
# CV with eta=0.03
# 	Merror 0.267574 for 16 rounds
# CV with eta=0.003
# 	Merror 0.2687076666666666 for 2 rounds
# CV with eta=0.0003
# 	Merror 0.2687076666666666 for 2 rounds

# %%
final_gb=xgb.train(param,dtrain,num_boost_round=num_round,
                   early_stopping_rounds=5,evals=[(dtest, "Test")])
# Out:
# [0]	Test-merror:0.312169
# Will train until Test-merror hasn't improved in 5 rounds.
# [1]	Test-merror:0.275132
# [2]	Test-merror:0.275132
# [3]	Test-merror:0.285714
# [4]	Test-merror:0.269841
# [5]	Test-merror:0.259259
# [6]	Test-merror:0.269841
# [7]	Test-merror:0.259259
# [8]	Test-merror:0.26455
# [9]	Test-merror:0.269841
# [10]	Test-merror:0.285714
# Stopping. Best iteration:
# [5]	Test-merror:0.259259

# %%
feature_plot = xgb.plot_importance(final_gb)

# %%
ypred = final_gb.predict(dtest)
ypred
# Out:
# array([[0.05587578, 0.9441242 ],
#        [0.05587578, 0.9441242 ],
#        [0.06081085, 0.93918914],
#        [0.16410844, 0.83589154],
#        [0.1422083 , 0.85779166],
#        [0.3968859 , 0.6031141 ],
#        [0.16455428, 0.83544576],
#        [0.720384  , 0.279616  ],
#        [0.05046659, 0.9495334 ],
#        [0.10674394, 0.89325607],
#        [0.06207606, 0.93792397],
#        [0.12008003, 0.87992   ],
#        [0.2681736 , 0.73182636],
#        [0.20362212, 0.79637784],
#        [0.52805847, 0.47194156],
#        [0.5777544 , 0.42224556],
#        [0.04514173, 0.9548583 ],
#        [0.04837352, 0.9516264 ],
#        [0.0818226 , 0.91817737],
#        [0.09018711, 0.9098129 ],
#        [0.17831527, 0.8216847 ],
#        [0.36444986, 0.63555014],
#        [0.3774267 , 0.6225733 ],
#        [0.5082805 , 0.4917195 ],
#        [0.0562077 , 0.9437923 ],
#        [0.13627613, 0.8637239 ],
#        [0.22822942, 0.7717706 ],
#        [0.09964725, 0.9003527 ],
#        [0.22619307, 0.7738069 ],
#        [0.36499947, 0.63500047],
#        [0.6169886 , 0.38301134],
#        [0.474272  , 0.525728  ],
#        [0.11870895, 0.8812911 ],
#        [0.25853795, 0.74146205],
#        [0.40205935, 0.5979407 ],
#        [0.2006042 , 0.79939574],
#        [0.1781602 , 0.82183975],
#        [0.25325978, 0.7467402 ],
#        [0.12069842, 0.87930155],
#        [0.12819295, 0.8718071 ],
#        [0.1535593 , 0.8464407 ],
#        [0.44015598, 0.55984396],
#        [0.43682894, 0.563171  ],
#        [0.36444986, 0.63555014],
#        [0.13701886, 0.86298114],
#        [0.09862616, 0.90137386],
#        [0.41021526, 0.5897848 ],
#        [0.25270772, 0.7472922 ],
#        [0.14398578, 0.8560142 ],
#        [0.40101415, 0.5989859 ],
#        [0.5031222 , 0.49687782],
#        [0.38816977, 0.6118303 ],
#        [0.22904336, 0.77095664],
#        [0.42311856, 0.5768814 ],
#        [0.24680188, 0.7531981 ],
#        [0.54948497, 0.45051506],
#        [0.31478795, 0.685212  ],
#        [0.6066598 , 0.39334014],
#        [0.14912431, 0.8508757 ],
#        [0.10860946, 0.89139056],
#        [0.40966052, 0.5903395 ],
#        [0.16565338, 0.83434665],
#        [0.41143268, 0.58856726],
#        [0.05411736, 0.9458826 ],
#        [0.06275211, 0.93724793],
#        [0.08824648, 0.9117535 ],
#        [0.08720331, 0.9127967 ],
#        [0.15792921, 0.84207076],
#        [0.14628093, 0.8537191 ],
#        [0.450428  , 0.549572  ],
#        [0.40531358, 0.59468645],
#        [0.09268056, 0.9073194 ],
#        [0.04663638, 0.9533636 ],
#        [0.0672287 , 0.93277127],
#        [0.07576886, 0.9242311 ],
#        [0.15106925, 0.8489307 ],
#        [0.5588598 , 0.4411402 ],
#        [0.33127853, 0.6687215 ],
#        [0.6358062 , 0.36419377],
#        [0.05046659, 0.9495334 ],
#        [0.05076811, 0.94923186],
#        [0.05495172, 0.94504833],
#        [0.14597519, 0.85402477],
#        [0.06936728, 0.9306327 ],
#        [0.36810097, 0.63189906],
#        [0.5334118 , 0.46658823],
#        [0.5889849 , 0.41101506],
#        [0.05150319, 0.94849676],
#        [0.05001024, 0.94998974],
#        [0.07345331, 0.9265467 ],
#        [0.07817268, 0.92182726],
#        [0.28590858, 0.7140915 ],
#        [0.4613945 , 0.5386056 ],
#        [0.725311  , 0.27468905],
#        [0.4601419 , 0.5398581 ],
#        [0.23739904, 0.76260096],
#        [0.25306618, 0.7469338 ],
#        [0.17186148, 0.82813853],
#        [0.35770538, 0.64229465],
#        [0.1142746 , 0.88572544],
#        [0.37322772, 0.6267722 ],
#        [0.24945825, 0.7505417 ],
#        [0.34176615, 0.6582338 ],
#        [0.16811132, 0.8318887 ],
#        [0.3982964 , 0.60170364],
#        [0.1563667 , 0.8436333 ],
#        [0.5483693 , 0.45163074],
#        [0.1130931 , 0.88690686],
#        [0.28161654, 0.71838343],
#        [0.32432657, 0.6756734 ],
#        [0.28138146, 0.7186185 ],
#        [0.23518686, 0.7648131 ],
#        [0.41298953, 0.58701044],
#        [0.29300228, 0.70699775],
#        [0.26505068, 0.73494935],
#        [0.299563  , 0.70043707],
#        [0.5007594 , 0.49924058],
#        [0.21236491, 0.7876351 ],
#        [0.32177478, 0.6782253 ],
#        [0.21013272, 0.7898672 ],
#        [0.1598065 , 0.8401935 ],
#        [0.299563  , 0.70043707],
#        [0.46119165, 0.53880835],
#        [0.16452576, 0.8354743 ],
#        [0.3370072 , 0.66299284],
#        [0.39082667, 0.60917336],
#        [0.05046659, 0.9495334 ],
#        [0.0825191 , 0.91748095],
#        [0.06275211, 0.93724793],
#        [0.15110376, 0.8488962 ],
#        [0.2073952 , 0.79260486],
#        [0.33685872, 0.66314125],
#        [0.44818476, 0.5518152 ],
#        [0.5612559 , 0.4387441 ],
#        [0.05411736, 0.9458826 ],
#        [0.04801982, 0.95198023],
#        [0.06696554, 0.9330345 ],
#        [0.12585929, 0.8741407 ],
#        [0.11883759, 0.8811624 ],
#        [0.4797224 , 0.5202776 ],
#        [0.31846827, 0.6815317 ],
#        [0.4377912 , 0.5622088 ],
#        [0.05587578, 0.9441242 ],
#        [0.06554183, 0.9344582 ],
#        [0.0672287 , 0.93277127],
#        [0.12932429, 0.87067574],
#        [0.12553275, 0.87446725],
#        [0.17000334, 0.8299967 ],
#        [0.46216378, 0.53783625],
#        [0.4784944 , 0.52150565],
#        [0.06490685, 0.9350931 ],
#        [0.07134968, 0.9286503 ],
#        [0.10453786, 0.89546216],
#        [0.07076674, 0.9292333 ],
#        [0.21953863, 0.7804614 ],
#        [0.45838818, 0.5416118 ],
#        [0.5561738 , 0.44382617],
#        [0.39734504, 0.60265493],
#        [0.08306199, 0.91693795],
#        [0.3664443 , 0.6335557 ],
#        [0.17675644, 0.82324356],
#        [0.133284  , 0.866716  ],
#        [0.36727902, 0.63272095],
#        [0.2637826 , 0.7362174 ],
#        [0.31723958, 0.6827604 ],
#        [0.47641867, 0.52358127],
#        [0.11633613, 0.8836639 ],
#        [0.17290245, 0.8270976 ],
#        [0.43882734, 0.56117266],
#        [0.06533046, 0.93466955],
#        [0.25018457, 0.7498154 ],
#        [0.22246514, 0.7775349 ],
#        [0.2388548 , 0.76114523],
#        [0.5074332 , 0.4925668 ],
#        [0.3141053 , 0.68589467],
#        [0.3752118 , 0.62478817],
#        [0.31496382, 0.6850362 ],
#        [0.40949327, 0.59050673],
#        [0.17632939, 0.82367057],
#        [0.47026613, 0.52973384],
#        [0.2586936 , 0.7413064 ],
#        [0.16781619, 0.83218384],
#        [0.3723005 , 0.62769943],
#        [0.2136939 , 0.78630614],
#        [0.17426866, 0.82573134],
#        [0.5274421 , 0.47255793],
#        [0.14982903, 0.85017097],
#        [0.6019357 , 0.39806437],
#        [0.26997846, 0.73002154]], dtype=float32)

# %%
print(ypred.shape)
print(testing_labels.shape)
# Out:
# (189, 2)
# (189, 1)

# %%
correct_list = np.zeros_like(testing_labels)
for i in range(len(ypred)):
    if ypred[i][0] < ypred[i][1]:
        metric = 1 # team A predicted to win
    else:
        metric = 0
    correct_list[i][0] = metric
    print("TeamA Win% {:.4}  SeedDiff {}".format(ypred[i][1]*100,testing_data[i][4]*-1))
# Out:
# TeamA Win% 94.41  SeedDiff 15.0
# TeamA Win% 94.41  SeedDiff 13.0
# TeamA Win% 93.92  SeedDiff 11.0
# TeamA Win% 83.59  SeedDiff 9.0
# TeamA Win% 85.78  SeedDiff 7.0
# TeamA Win% 60.31  SeedDiff 5.0
# TeamA Win% 83.54  SeedDiff 3.0
# TeamA Win% 27.96  SeedDiff 1.0
# TeamA Win% 94.95  SeedDiff 15.0
# TeamA Win% 89.33  SeedDiff 13.0
# TeamA Win% 93.79  SeedDiff 11.0
# TeamA Win% 87.99  SeedDiff 9.0
# TeamA Win% 73.18  SeedDiff 7.0
# TeamA Win% 79.64  SeedDiff 5.0
# TeamA Win% 47.19  SeedDiff 3.0
# TeamA Win% 42.22  SeedDiff 1.0
# TeamA Win% 95.49  SeedDiff 15.0
# TeamA Win% 95.16  SeedDiff 13.0
# TeamA Win% 91.82  SeedDiff 11.0
# TeamA Win% 90.98  SeedDiff 9.0
# TeamA Win% 82.17  SeedDiff 7.0
# TeamA Win% 63.56  SeedDiff 5.0
# TeamA Win% 62.26  SeedDiff 3.0
# TeamA Win% 49.17  SeedDiff 1.0
# TeamA Win% 94.38  SeedDiff 15.0
# TeamA Win% 86.37  SeedDiff 13.0
# TeamA Win% 77.18  SeedDiff 11.0
# TeamA Win% 90.04  SeedDiff 9.0
# TeamA Win% 77.38  SeedDiff 7.0
# TeamA Win% 63.5  SeedDiff 5.0
# TeamA Win% 38.3  SeedDiff 3.0
# TeamA Win% 52.57  SeedDiff 1.0
# TeamA Win% 88.13  SeedDiff 8.0
# TeamA Win% 74.15  SeedDiff 5.0
# TeamA Win% 59.79  SeedDiff 8.0
# TeamA Win% 79.94  SeedDiff 8.0
# TeamA Win% 82.18  SeedDiff 7.0
# TeamA Win% 74.67  SeedDiff 8.0
# TeamA Win% 87.93  SeedDiff 8.0
# TeamA Win% 87.18  SeedDiff 8.0
# TeamA Win% 84.64  SeedDiff 8.0
# TeamA Win% 55.98  SeedDiff 5.0
# TeamA Win% 56.32  SeedDiff 8.0
# TeamA Win% 63.56  SeedDiff 1.0
# TeamA Win% 86.3  SeedDiff 8.0
# TeamA Win% 90.14  SeedDiff 5.0
# TeamA Win% 58.98  SeedDiff 8.0
# TeamA Win% 74.73  SeedDiff 8.0
# TeamA Win% 85.6  SeedDiff 4.0
# TeamA Win% 59.9  SeedDiff 1.0
# TeamA Win% 49.69  SeedDiff 3.0
# TeamA Win% 61.18  SeedDiff 1.0
# TeamA Win% 77.1  SeedDiff 4.0
# TeamA Win% 57.69  SeedDiff 1.0
# TeamA Win% 75.32  SeedDiff 3.0
# TeamA Win% 45.05  SeedDiff 1.0
# TeamA Win% 68.52  SeedDiff 1.0
# TeamA Win% 39.33  SeedDiff 1.0
# TeamA Win% 85.09  SeedDiff 5.0
# TeamA Win% 89.14  SeedDiff 9.0
# TeamA Win% 59.03  SeedDiff -0.0
# TeamA Win% 83.43  SeedDiff 9.0
# TeamA Win% 58.86  SeedDiff 1.0
# TeamA Win% 94.59  SeedDiff 15.0
# TeamA Win% 93.72  SeedDiff 13.0
# TeamA Win% 91.18  SeedDiff 11.0
# TeamA Win% 91.28  SeedDiff 9.0
# TeamA Win% 84.21  SeedDiff 7.0
# TeamA Win% 85.37  SeedDiff 5.0
# TeamA Win% 54.96  SeedDiff 3.0
# TeamA Win% 59.47  SeedDiff 1.0
# TeamA Win% 90.73  SeedDiff 15.0
# TeamA Win% 95.34  SeedDiff 13.0
# TeamA Win% 93.28  SeedDiff 11.0
# TeamA Win% 92.42  SeedDiff 9.0
# TeamA Win% 84.89  SeedDiff 7.0
# TeamA Win% 44.11  SeedDiff 5.0
# TeamA Win% 66.87  SeedDiff 3.0
# TeamA Win% 36.42  SeedDiff 1.0
# TeamA Win% 94.95  SeedDiff 15.0
# TeamA Win% 94.92  SeedDiff 13.0
# TeamA Win% 94.5  SeedDiff 11.0
# TeamA Win% 85.4  SeedDiff 9.0
# TeamA Win% 93.06  SeedDiff 7.0
# TeamA Win% 63.19  SeedDiff 5.0
# TeamA Win% 46.66  SeedDiff 3.0
# TeamA Win% 41.1  SeedDiff 1.0
# TeamA Win% 94.85  SeedDiff 15.0
# TeamA Win% 95.0  SeedDiff 13.0
# TeamA Win% 92.65  SeedDiff 11.0
# TeamA Win% 92.18  SeedDiff 9.0
# TeamA Win% 71.41  SeedDiff 7.0
# TeamA Win% 53.86  SeedDiff 5.0
# TeamA Win% 27.47  SeedDiff 3.0
# TeamA Win% 53.99  SeedDiff 1.0
# TeamA Win% 76.26  SeedDiff 7.0
# TeamA Win% 74.69  SeedDiff 5.0
# TeamA Win% 82.81  SeedDiff 8.0
# TeamA Win% 64.23  SeedDiff 1.0
# TeamA Win% 88.57  SeedDiff 7.0
# TeamA Win% 62.68  SeedDiff 5.0
# TeamA Win% 75.05  SeedDiff 8.0
# TeamA Win% 65.82  SeedDiff 1.0
# TeamA Win% 83.19  SeedDiff 8.0
# TeamA Win% 60.17  SeedDiff 5.0
# TeamA Win% 84.36  SeedDiff 8.0
# TeamA Win% 45.16  SeedDiff 1.0
# TeamA Win% 88.69  SeedDiff 7.0
# TeamA Win% 71.84  SeedDiff 8.0
# TeamA Win% 67.57  SeedDiff 3.0
# TeamA Win% 71.86  SeedDiff 8.0
# TeamA Win% 76.48  SeedDiff 4.0
# TeamA Win% 58.7  SeedDiff 4.0
# TeamA Win% 70.7  SeedDiff 3.0
# TeamA Win% 73.49  SeedDiff 9.0
# TeamA Win% 70.04  SeedDiff 3.0
# TeamA Win% 49.92  SeedDiff 4.0
# TeamA Win% 78.76  SeedDiff 3.0
# TeamA Win% 67.82  SeedDiff 1.0
# TeamA Win% 78.99  SeedDiff 3.0
# TeamA Win% 84.02  SeedDiff 10.0
# TeamA Win% 70.04  SeedDiff 2.0
# TeamA Win% 53.88  SeedDiff 1.0
# TeamA Win% 83.55  SeedDiff 6.0
# TeamA Win% 66.3  SeedDiff 2.0
# TeamA Win% 60.92  SeedDiff -0.0
# TeamA Win% 94.95  SeedDiff 15.0
# TeamA Win% 91.75  SeedDiff 13.0
# TeamA Win% 93.72  SeedDiff 11.0
# TeamA Win% 84.89  SeedDiff 9.0
# TeamA Win% 79.26  SeedDiff 7.0
# TeamA Win% 66.31  SeedDiff 5.0
# TeamA Win% 55.18  SeedDiff 3.0
# TeamA Win% 43.87  SeedDiff 1.0
# TeamA Win% 94.59  SeedDiff 15.0
# TeamA Win% 95.2  SeedDiff 13.0
# TeamA Win% 93.3  SeedDiff 11.0
# TeamA Win% 87.41  SeedDiff 9.0
# TeamA Win% 88.12  SeedDiff 7.0
# TeamA Win% 52.03  SeedDiff 5.0
# TeamA Win% 68.15  SeedDiff 3.0
# TeamA Win% 56.22  SeedDiff 1.0
# TeamA Win% 94.41  SeedDiff 15.0
# TeamA Win% 93.45  SeedDiff 13.0
# TeamA Win% 93.28  SeedDiff 11.0
# TeamA Win% 87.07  SeedDiff 9.0
# TeamA Win% 87.45  SeedDiff 7.0
# TeamA Win% 83.0  SeedDiff 5.0
# TeamA Win% 53.78  SeedDiff 3.0
# TeamA Win% 52.15  SeedDiff 1.0
# TeamA Win% 93.51  SeedDiff 15.0
# TeamA Win% 92.87  SeedDiff 13.0
# TeamA Win% 89.55  SeedDiff 11.0
# TeamA Win% 92.92  SeedDiff 9.0
# TeamA Win% 78.05  SeedDiff 7.0
# TeamA Win% 54.16  SeedDiff 5.0
# TeamA Win% 44.38  SeedDiff 3.0
# TeamA Win% 60.27  SeedDiff 1.0
# TeamA Win% 91.69  SeedDiff 7.0
# TeamA Win% 63.36  SeedDiff 5.0
# TeamA Win% 82.32  SeedDiff 8.0
# TeamA Win% 86.67  SeedDiff 8.0
# TeamA Win% 63.27  SeedDiff 8.0
# TeamA Win% 73.62  SeedDiff 5.0
# TeamA Win% 68.28  SeedDiff 3.0
# TeamA Win% 52.36  SeedDiff 1.0
# TeamA Win% 88.37  SeedDiff 8.0
# TeamA Win% 82.71  SeedDiff 8.0
# TeamA Win% 56.12  SeedDiff 3.0
# TeamA Win% 93.47  SeedDiff 8.0
# TeamA Win% 74.98  SeedDiff 7.0
# TeamA Win% 77.75  SeedDiff 5.0
# TeamA Win% 76.11  SeedDiff 8.0
# TeamA Win% 49.26  SeedDiff 1.0
# TeamA Win% 68.59  SeedDiff 4.0
# TeamA Win% 62.48  SeedDiff 4.0
# TeamA Win% 68.5  SeedDiff 5.0
# TeamA Win% 59.05  SeedDiff 4.0
# TeamA Win% 82.37  SeedDiff 4.0
# TeamA Win% 52.97  SeedDiff 1.0
# TeamA Win% 74.13  SeedDiff 4.0
# TeamA Win% 83.22  SeedDiff 9.0
# TeamA Win% 62.77  SeedDiff 2.0
# TeamA Win% 78.63  SeedDiff 6.0
# TeamA Win% 82.57  SeedDiff 2.0
# TeamA Win% 47.26  SeedDiff 1.0
# TeamA Win% 85.02  SeedDiff 8.0
# TeamA Win% 39.81  SeedDiff -0.0
# TeamA Win% 73.0  SeedDiff 2.0

# %%
print("% Correct: ", (correct_list.sum() / len(correct_list))*100)
# Out:
# % Correct:  89.41798941798942

# %%
# The next many cells of code are for creating the bracket for 2018
# Each round needs to be run seperately, as the teams competing in each
# round is contingent on the last, obviously.
# As a result, there are 6 cells that need to be run to create the bracket

res_data_2018 = res_data_test[res_data_test['Year'] == 2018]
stats_data_2018 = stats_data_test[stats_data_test['Season'] == 2018]

res_data_2018 = res_data_2018.reset_index(drop=True)
stats_data_2018 = stats_data_2018.reset_index(drop=True)

r64_2018_data = np.zeros((32,13))
r64_2018_labels = np.zeros((32,1))
r64_2018_teams = []

for i in range(32):
    year = res_data_2018['Year'][i]
    teamA = res_data_2018['TeamA'][i]
    teamB = res_data_2018['TeamB'][i]
    score_diff = res_data_2018['ScoreA'][i] - res_data_2018['ScoreB'][i]
    for k in range(len(stats_data_2018)):
        if ((stats_data_2018['Season'][k] == year) and (stats_data_2018['TeamName'][k] == teamA)):
            indexA = k
            break
            
    for k in range(len(stats_data_train)):
        if ((stats_data_2018['Season'][k] == year) and (stats_data_2018['TeamName'][k] == teamB)):
            indexB = k
            break
    for s in range(len(stats_vec)):
        stat = stats_vec[s]
        r64_2018_data[i][s] = stats_data_2018[stat][indexA] - stats_data_2018[stat][indexB]
    
    if (score_diff > 0): # team A won
        r64_2018_labels[i][0] = 1
    else:
        r64_2018_labels[i][0] = 0 #team B won
    r64_2018_teams.append([teamA,teamB])

r64_2018_data = preprocessing.normalize(r64_2018_data, axis=0, norm='max')
r64_2018_dmatrix = xgb.DMatrix(r64_2018_data, label=r64_2018_labels,
                    feature_names=stats_vec)

r64_2018_pred = final_gb.predict(r64_2018_dmatrix)

#0 index is teamB win - 1 index is teamA win
print("\n\nRound of 64 Predictions - 2018")
for i in range(len(r64_2018_pred)):
    teamA = r64_2018_teams[i][0]
    teamB = r64_2018_teams[i][1]
    if r64_2018_pred[i][1] > r64_2018_pred[i][0]: #team A win
        print("Winner:", teamA)
        print("Loser: ", teamB, '\n')
    else: #team B win
        print("Winner:", teamB)
        print("Loser: ", teamA, '\n')
# Out:
# Round of 64 Predictions - 2018
# Winner: Virginia
# Loser:  UMBC
#
# Winner: Cincinnati
# Loser:  Georgia St
#
# Winner: Tennessee
# Loser:  Wright St
#
# Winner: Arizona
# Loser:  Buffalo
#
# Winner: Kentucky
# Loser:  Davidson
#
# Winner: Miami
# Loser:  Loyola Chicago
#
# Winner: Nevada
# Loser:  Texas
#
# Winner: Kansas St
# Loser:  Creighton
#
# Winner: Xavier
# Loser:  Texas Southern
#
# Winner: North Carolina
# Loser:  Lipscomb
#
# Winner: Michigan
# Loser:  Montana
#
# Winner: Gonzaga
# Loser:  UNC Greensboro
#
# Winner: Ohio St
# Loser:  South Dakota St
#
# Winner: Houston
# Loser:  San Diego St
#
# Winner: Texas A&M
# Loser:  Providence
#
# Winner: Missouri
# Loser:  Florida St
#
# Winner: Villanova
# Loser:  Radford
#
# Winner: Purdue
# Loser:  Cal St Fullerton
#
# Winner: Texas Tech
# Loser:  Stephen F Austin
#
# Winner: Wichita St
# Loser:  Marshall
#
# Winner: West Virginia
# Loser:  Murray St
#
# Winner: Florida
# Loser:  St Bonaventure
#
# Winner: Arkansas
# Loser:  Butler
#
# Winner: Virginia Tech
# Loser:  Alabama
#
# Winner: Kansas
# Loser:  Pennsylvania
#
# Winner: Duke
# Loser:  Iona
#
# Winner: Michigan St
# Loser:  Bucknell
#
# Winner: Auburn
# Loser:  College of Charleston
#
# Winner: Clemson
# Loser:  New Mexico St
#
# Winner: TCU
# Loser:  Syracuse
#
# Winner: Oklahoma
# Loser:  Rhode Island
#
# Winner: Seton Hall
# Loser:  NC State

# %%
# As you can see, I manually read through the results of each round to
# create the matchups for the next round by hand

r32_2018_teams = [["Virginia","Kansas St"],
                  ["Arizona","Kentucky"],
                  ["Tennessee","Miami"],
                  ["Cincinnati","Nevada"],
                  ["Xavier","Missouri"],
                  ["Gonzaga","Ohio State"],
                  ["Michigan","Houston"],
                  ["North Carolina","Texas A&M"],
                  ["Villanova","Virginia Tech"],
                  ["Wichita St","West Virginia"],
                  ["Texas Tech","Florida"],
                  ["Purdue","Arkansas"],
                  ["Kansas","Seton Hall"],
                  ["Auburn","Clemson"],
                  ["Michigan St","TCU"],
                  ["Duke","Oklahoma"]]

r32_2018_data = np.zeros((16,13))
r32_2018_labels = np.zeros((16,1))

for i in range(16):
    year = 2018
    teamA = r32_2018_teams[i][0]
    teamB = r32_2018_teams[i][1]
    for k in range(len(stats_data_2018)):
        if ((stats_data_2018['Season'][k] == year) and (stats_data_2018['TeamName'][k] == teamA)):
            indexA = k
            break
            
    for k in range(len(stats_data_2018)):
        if ((stats_data_2018['Season'][k] == year) and (stats_data_2018['TeamName'][k] == teamB)):
            indexB = k
            break
    for s in range(len(stats_vec)):
        stat = stats_vec[s]
        r32_2018_data[i][s] = stats_data_2018[stat][indexA] - stats_data_2018[stat][indexB]

r32_2018_data = preprocessing.normalize(r32_2018_data, axis=0, norm='max')
r32_2018_dmatrix = xgb.DMatrix(r32_2018_data, label=r32_2018_labels,
                    feature_names=stats_vec)
r32_2018_pred = final_gb.predict(r32_2018_dmatrix)
#0 index is teamB win - 1 index is teamA win
print("\n\nRound of 32 Predictions - 2018")
for i in range(len(r32_2018_pred)):
    teamA = r32_2018_teams[i][0]
    teamB = r32_2018_teams[i][1]
    if r32_2018_pred[i][1] > r32_2018_pred[i][0]: #team A win
        print("Winner:", teamA)
        print("Loser: ", teamB, '\n')
    else: #team B win
        print("Winner:", teamB)
        print("Loser: ", teamA, '\n')
# Out:
# Round of 32 Predictions - 2018
# Winner: Virginia
# Loser:  Kansas St
#
# Winner: Kentucky
# Loser:  Arizona
#
# Winner: Tennessee
# Loser:  Miami
#
# Winner: Cincinnati
# Loser:  Nevada
#
# Winner: Xavier
# Loser:  Missouri
#
# Winner: Gonzaga
# Loser:  Ohio State
#
# Winner: Michigan
# Loser:  Houston
#
# Winner: North Carolina
# Loser:  Texas A&M
#
# Winner: Villanova
# Loser:  Virginia Tech
#
# Winner: Wichita St
# Loser:  West Virginia
#
# Winner: Texas Tech
# Loser:  Florida
#
# Winner: Purdue
# Loser:  Arkansas
#
# Winner: Kansas
# Loser:  Seton Hall
#
# Winner: Clemson
# Loser:  Auburn
#
# Winner: Michigan St
# Loser:  TCU
#
# Winner: Duke
# Loser:  Oklahoma

# %%
r16_2018_teams = [["Virginia","Kentucky"],
                  ["Cincinnati","Tennessee"],
                  ["Xavier","Gonzaga"],
                  ["North Carolina","Michigan"],
                  ["Villanova","Wichita St"],
                  ["Purdue","Texas Tech"],
                  ["Kansas","Clemson"],
                  ["Duke","Michigan St"]]

r16_2018_data = np.zeros((8,13))
r16_2018_labels = np.zeros((8,1))

for i in range(8):
    year = 2018
    teamA = r16_2018_teams[i][0]
    teamB = r16_2018_teams[i][1]
    for k in range(len(stats_data_2018)):
        if ((stats_data_2018['Season'][k] == year) and (stats_data_2018['TeamName'][k] == teamA)):
            indexA = k
            break
            
    for k in range(len(stats_data_2018)):
        if ((stats_data_2018['Season'][k] == year) and (stats_data_2018['TeamName'][k] == teamB)):
            indexB = k
            break
    for s in range(len(stats_vec)):
        stat = stats_vec[s]
        r16_2018_data[i][s] = stats_data_2018[stat][indexA] - stats_data_2018[stat][indexB]
        
r16_2018_data = preprocessing.normalize(r16_2018_data, axis=0, norm='max')
r16_2018_dmatrix = xgb.DMatrix(r16_2018_data, label=r16_2018_labels,
                    feature_names=stats_vec)
r16_2018_pred = final_gb.predict(r16_2018_dmatrix)
#0 index is teamB win - 1 index is teamA win
print("\n\nSweet 16 Predictions - 2018")
for i in range(len(r16_2018_pred)):
    teamA = r16_2018_teams[i][0]
    teamB = r16_2018_teams[i][1]
    if r16_2018_pred[i][1] > r16_2018_pred[i][0]: #team A win
        print("Winner:", teamA)
        print("Loser: ", teamB, '\n')
    else: #team B win
        print("Winner:", teamB)
        print("Loser: ", teamA, '\n')
# Out:
# Sweet 16 Predictions - 2018
# Winner: Virginia
# Loser:  Kentucky
#
# Winner: Cincinnati
# Loser:  Tennessee
#
# Winner: Xavier
# Loser:  Gonzaga
#
# Winner: North Carolina
# Loser:  Michigan
#
# Winner: Villanova
# Loser:  Wichita St
#
# Winner: Purdue
# Loser:  Texas Tech
#
# Winner: Kansas
# Loser:  Clemson
#
# Winner: Duke
# Loser:  Michigan St

# %%
r8_2018_teams = [["Virginia","Cincinnati"],
                 ["North Carolina","Xavier"],
                 ["Villanova","Purdue"],
                 ["Kansas","Duke"]]

r8_2018_data = np.zeros((4,13))
r8_2018_labels = np.zeros((4,1))

for i in range(4):
    year = 2018
    teamA = r8_2018_teams[i][0]
    teamB = r8_2018_teams[i][1]
    for k in range(len(stats_data_2018)):
        if ((stats_data_2018['Season'][k] == year) and (stats_data_2018['TeamName'][k] == teamA)):
            indexA = k
            break
            
    for k in range(len(stats_data_2018)):
        if ((stats_data_2018['Season'][k] == year) and (stats_data_2018['TeamName'][k] == teamB)):
            indexB = k
            break
    for s in range(len(stats_vec)):
        stat = stats_vec[s]
        r8_2018_data[i][s] = stats_data_2018[stat][indexA] - stats_data_2018[stat][indexB]
        
r8_2018_data = preprocessing.normalize(r8_2018_data, axis=0, norm='max')
r8_2018_dmatrix = xgb.DMatrix(r8_2018_data, label=r8_2018_labels,
                    feature_names=stats_vec)
r8_2018_pred = final_gb.predict(r8_2018_dmatrix)
#0 index is teamB win - 1 index is teamA win
print("\n\nElite 8 Predictions - 2018")
for i in range(len(r8_2018_pred)):
    teamA = r8_2018_teams[i][0]
    teamB = r8_2018_teams[i][1]
    if r8_2018_pred[i][1] > r8_2018_pred[i][0]: #team A win
        print("Winner:", teamA)
        print("Loser: ", teamB, '\n')
    else: #team B win
        print("Winner:", teamB)
        print("Loser: ", teamA, '\n')
# Out:
# Elite 8 Predictions - 2018
# Winner: Virginia
# Loser:  Cincinnati
#
# Winner: North Carolina
# Loser:  Xavier
#
# Winner: Villanova
# Loser:  Purdue
#
# Winner: Duke
# Loser:  Kansas

# %%
r4_2018_teams = [["Virginia","North Carolina"],
                 ["Villanova","Duke"]]

r4_2018_data = np.zeros((2,13))
r4_2018_labels = np.zeros((2,1))

for i in range(2):
    year = 2018
    teamA = r4_2018_teams[i][0]
    teamB = r4_2018_teams[i][1]
    for k in range(len(stats_data_2018)):
        if ((stats_data_2018['Season'][k] == year) and (stats_data_2018['TeamName'][k] == teamA)):
            indexA = k
            break
            
    for k in range(len(stats_data_2018)):
        if ((stats_data_2018['Season'][k] == year) and (stats_data_2018['TeamName'][k] == teamB)):
            indexB = k
            break
    for s in range(len(stats_vec)):
        stat = stats_vec[s]
        r4_2018_data[i][s] = stats_data_2018[stat][indexA] - stats_data_2018[stat][indexB]
        
r4_2018_data = preprocessing.normalize(r4_2018_data, axis=0, norm='max')
r4_2018_dmatrix = xgb.DMatrix(r4_2018_data, label=r4_2018_labels,
                    feature_names=stats_vec)
r4_2018_pred = final_gb.predict(r4_2018_dmatrix)
#0 index is teamB win - 1 index is teamA win
print("\n\nFinal 4 Predictions - 2018")
for i in range(len(r4_2018_pred)):
    teamA = r4_2018_teams[i][0]
    teamB = r4_2018_teams[i][1]
    if r4_2018_pred[i][1] > r4_2018_pred[i][0]: #team A win
        print("Winner:", teamA)
        print("Loser: ", teamB, '\n')
    else: #team B win
        print("Winner:", teamB)
        print("Loser: ", teamA, '\n')
# Out:
# Final 4 Predictions - 2018
# Winner: Virginia
# Loser:  North Carolina
#
# Winner: Villanova
# Loser:  Duke

# %%
r2_2018_teams = [["Virginia","Villanova"]]

r2_2018_data = np.zeros((1,13))
r2_2018_labels = np.zeros((1,1))

for i in range(1):
    year = 2018
    teamA = r2_2018_teams[i][0]
    teamB = r2_2018_teams[i][1]
    for k in range(len(stats_data_2018)):
        if ((stats_data_2018['Season'][k] == year) and (stats_data_2018['TeamName'][k] == teamA)):
            indexA = k
            break
            
    for k in range(len(stats_data_2018)):
        if ((stats_data_2018['Season'][k] == year) and (stats_data_2018['TeamName'][k] == teamB)):
            indexB = k
            break
    for s in range(len(stats_vec)):
        stat = stats_vec[s]
        r2_2018_data[i][s] = stats_data_2018[stat][indexA] - stats_data_2018[stat][indexB]
        
r2_2018_data = preprocessing.normalize(r2_2018_data, axis=0, norm='max')
r2_2018_dmatrix = xgb.DMatrix(r2_2018_data, label=r2_2018_labels,
                    feature_names=stats_vec)
r2_2018_pred = final_gb.predict(r2_2018_dmatrix)
#0 index is teamB win - 1 index is teamA win
print("\n\nNational Championship Prediction - 2018")
for i in range(len(r2_2018_pred)):
    teamA = r2_2018_teams[i][0]
    teamB = r2_2018_teams[i][1]
    if r2_2018_pred[i][1] > r2_2018_pred[i][0]: #team A win
        print("Winner:", teamA)
        print("Loser: ", teamB, '\n')
    else: #team B win
        print("Winner:", teamB)
        print("Loser: ", teamA, '\n')
# Out:
# National Championship Prediction - 2018
# Winner: Virginia
# Loser:  Villanova

# %%
# Now, I did the same for 2017, just to see how well we would do when a
# historic upset does NOT occur in the first round

res_data_2017 = res_data_test[res_data_test['Year'] == 2017]
stats_data_2017 = stats_data_test[stats_data_test['Season'] == 2017]

res_data_2017 = res_data_2017.reset_index(drop=True)
stats_data_2017 = stats_data_2017.reset_index(drop=True)

r64_2017_data = np.zeros((32,13))
r64_2017_labels = np.zeros((32,1))
r64_2017_teams = []

for i in range(32):
    year = res_data_2017['Year'][i]
    teamA = res_data_2017['TeamA'][i]
    teamB = res_data_2017['TeamB'][i]
    score_diff = res_data_2017['ScoreA'][i] - res_data_2017['ScoreB'][i]
    for k in range(len(stats_data_2017)):
        if ((stats_data_2017['Season'][k] == year) and (stats_data_2017['TeamName'][k] == teamA)):
            indexA = k
            break
            
    for k in range(len(stats_data_train)):
        if ((stats_data_2017['Season'][k] == year) and (stats_data_2017['TeamName'][k] == teamB)):
            indexB = k
            break
    for s in range(len(stats_vec)):
        stat = stats_vec[s]
        r64_2017_data[i][s] = stats_data_2017[stat][indexA] - stats_data_2017[stat][indexB]
    
    if (score_diff > 0): # team A won
        r64_2017_labels[i][0] = 1
    else:
        r64_2017_labels[i][0] = 0 #team B won
    r64_2017_teams.append([teamA,teamB])

r64_2017_data = preprocessing.normalize(r64_2017_data, axis=0, norm='max')
r64_2017_dmatrix = xgb.DMatrix(r64_2017_data, label=r64_2017_labels,
                    feature_names=stats_vec)

r64_2017_pred = final_gb.predict(r64_2017_dmatrix)

#0 index is teamB win - 1 index is teamA win
print("\n\nRound of 64 Predictions - 2017")
for i in range(len(r64_2017_pred)):
    teamA = r64_2017_teams[i][0]
    teamB = r64_2017_teams[i][1]
    if r64_2017_pred[i][1] > r64_2017_pred[i][0]: #team A win
        print("Winner:", teamA)
        print("Loser: ", teamB, '\n')
    else: #team B win
        print("Winner:", teamB)
        print("Loser: ", teamA, '\n')
# Out:
# Round of 64 Predictions - 2017
# Winner: Villanova
# Loser:  Mount St Marys
#
# Winner: Duke
# Loser:  Troy
#
# Winner: Baylor
# Loser:  New Mexico St
#
# Winner: Florida
# Loser:  East Tennessee St
#
# Winner: Virginia
# Loser:  UNC Wilmington
#
# Winner: SMU
# Loser:  USC
#
# Winner: South Carolina
# Loser:  Marquette
#
# Winner: Wisconsin
# Loser:  Virginia Tech
#
# Winner: Gonzaga
# Loser:  South Dakota St
#
# Winner: Arizona
# Loser:  North Dakota
#
# Winner: Florida St
# Loser:  Florida Gulf Coast
#
# Winner: West Virginia
# Loser:  Bucknell
#
# Winner: Notre Dame
# Loser:  Princeton
#
# Winner: Xavier
# Loser:  Maryland
#
# Winner: St Marys
# Loser:  VCU
#
# Winner: Vanderbilt
# Loser:  Northwestern
#
# Winner: Kansas
# Loser:  UC Davis
#
# Winner: Louisville
# Loser:  Jacksonville St
#
# Winner: Oregon
# Loser:  Iona
#
# Winner: Purdue
# Loser:  Vermont
#
# Winner: Iowa St
# Loser:  Nevada
#
# Winner: Creighton
# Loser:  Rhode Island
#
# Winner: Michigan
# Loser:  Oklahoma St
#
# Winner: Michigan St
# Loser:  Miami
#
# Winner: North Carolina
# Loser:  Texas Southern
#
# Winner: Kentucky
# Loser:  Northern Kentucky
#
# Winner: UCLA
# Loser:  Kent St
#
# Winner: Butler
# Loser:  Winthrop
#
# Winner: Minnesota
# Loser:  Middle Tennessee St
#
# Winner: Cincinnati
# Loser:  Kansas St
#
# Winner: Wichita St
# Loser:  Dayton
#
# Winner: Arkansas
# Loser:  Seton Hall

# %%
r32_2017_teams = [["Villanova","Wisconsin"],
                  ["Florida","Virginia"],
                  ["Baylor","SMU"],
                  ["Duke","South Carolina"],
                  ["Gonzaga","Vanderbilt"],
                  ["West Virginia","Notre Dame"],
                  ["Florida St","Xavier"],
                  ["Arizona","St Marys"],
                  ["Kansas","Michigan St"],
                  ["Purdue","Iowa St"],
                  ["Oregon","Creighton"],
                  ["Louisville","Michigan"],
                  ["North Carolina","Arkansas"],
                  ["Butler","Minnesota"],
                  ["UCLA","Cincinnati"],
                  ["Kentucky","Wichita St"]]

r32_2017_data = np.zeros((16,13))
r32_2017_labels = np.zeros((16,1))

for i in range(16):
    year = 2017
    teamA = r32_2017_teams[i][0]
    teamB = r32_2017_teams[i][1]
    for k in range(len(stats_data_2017)):
        if ((stats_data_2017['Season'][k] == year) and (stats_data_2017['TeamName'][k] == teamA)):
            indexA = k
            break
            
    for k in range(len(stats_data_2017)):
        if ((stats_data_2017['Season'][k] == year) and (stats_data_2017['TeamName'][k] == teamB)):
            indexB = k
            break
    for s in range(len(stats_vec)):
        stat = stats_vec[s]
        r32_2017_data[i][s] = stats_data_2017[stat][indexA] - stats_data_2017[stat][indexB]

r32_2017_data = preprocessing.normalize(r32_2017_data, axis=0, norm='max')
r32_2017_dmatrix = xgb.DMatrix(r32_2017_data, label=r32_2017_labels,
                    feature_names=stats_vec)
r32_2017_pred = final_gb.predict(r32_2017_dmatrix)
#0 index is teamB win - 1 index is teamA win
print("\n\nRound of 32 Predictions - 2017")
for i in range(len(r32_2017_pred)):
    teamA = r32_2017_teams[i][0]
    teamB = r32_2017_teams[i][1]
    if r32_2017_pred[i][1] > r32_2017_pred[i][0]: #team A win
        print("Winner:", teamA)
        print("Loser: ", teamB, '\n')
    else: #team B win
        print("Winner:", teamB)
        print("Loser: ", teamA, '\n')
# Out:
# Round of 32 Predictions - 2017
# Winner: Villanova
# Loser:  Wisconsin
#
# Winner: Florida
# Loser:  Virginia
#
# Winner: SMU
# Loser:  Baylor
#
# Winner: Duke
# Loser:  South Carolina
#
# Winner: Gonzaga
# Loser:  Vanderbilt
#
# Winner: West Virginia
# Loser:  Notre Dame
#
# Winner: Florida St
# Loser:  Xavier
#
# Winner: Arizona
# Loser:  St Marys
#
# Winner: Kansas
# Loser:  Michigan St
#
# Winner: Purdue
# Loser:  Iowa St
#
# Winner: Oregon
# Loser:  Creighton
#
# Winner: Louisville
# Loser:  Michigan
#
# Winner: North Carolina
# Loser:  Arkansas
#
# Winner: Butler
# Loser:  Minnesota
#
# Winner: UCLA
# Loser:  Cincinnati
#
# Winner: Kentucky
# Loser:  Wichita St

# %%
r16_2017_teams = [["Villanova","Florida"],
                  ["Duke","SMU"],
                  ["Gonzaga","West Virginia"],
                  ["Arizona","Florida St"],
                  ["Kansas","Purdue"],
                  ["Louisville","Oregon"],
                  ["North Carolina","Butler"],
                  ["Kentucky","UCLA"]]

r16_2017_data = np.zeros((8,13))
r16_2017_labels = np.zeros((8,1))

for i in range(8):
    year = 2017
    teamA = r16_2017_teams[i][0]
    teamB = r16_2017_teams[i][1]
    for k in range(len(stats_data_2017)):
        if ((stats_data_2017['Season'][k] == year) and (stats_data_2017['TeamName'][k] == teamA)):
            indexA = k
            break
            
    for k in range(len(stats_data_2017)):
        if ((stats_data_2017['Season'][k] == year) and (stats_data_2017['TeamName'][k] == teamB)):
            indexB = k
            break
    for s in range(len(stats_vec)):
        stat = stats_vec[s]
        r16_2017_data[i][s] = stats_data_2017[stat][indexA] - stats_data_2017[stat][indexB]
        
r16_2017_data = preprocessing.normalize(r16_2017_data, axis=0, norm='max')
r16_2017_dmatrix = xgb.DMatrix(r16_2017_data, label=r16_2017_labels,
                    feature_names=stats_vec)
r16_2017_pred = final_gb.predict(r16_2017_dmatrix)
#0 index is teamB win - 1 index is teamA win
print("\n\nSweet 16 Predictions - 2017")
for i in range(len(r16_2017_pred)):
    teamA = r16_2017_teams[i][0]
    teamB = r16_2017_teams[i][1]
    if r16_2017_pred[i][1] > r16_2017_pred[i][0]: #team A win
        print("Winner:", teamA)
        print("Loser: ", teamB, '\n')
    else: #team B win
        print("Winner:", teamB)
        print("Loser: ", teamA, '\n')
# Out:
# Sweet 16 Predictions - 2017
# Winner: Villanova
# Loser:  Florida
#
# Winner: Duke
# Loser:  SMU
#
# Winner: Gonzaga
# Loser:  West Virginia
#
# Winner: Arizona
# Loser:  Florida St
#
# Winner: Kansas
# Loser:  Purdue
#
# Winner: Louisville
# Loser:  Oregon
#
# Winner: North Carolina
# Loser:  Butler
#
# Winner: Kentucky
# Loser:  UCLA

# %%
r8_2017_teams = [["Villanova","Duke"],
                 ["Gonzaga","Arizona"],
                 ["Kansas","Louisville"],
                 ["North Carolina","Kentucky"]]
r8_2017_data = np.zeros((4,13))
r8_2017_labels = np.zeros((4,1))

for i in range(4):
    year = 2017
    teamA = r8_2017_teams[i][0]
    teamB = r8_2017_teams[i][1]
    for k in range(len(stats_data_2017)):
        if ((stats_data_2017['Season'][k] == year) and (stats_data_2017['TeamName'][k] == teamA)):
            indexA = k
            break
            
    for k in range(len(stats_data_2017)):
        if ((stats_data_2017['Season'][k] == year) and (stats_data_2017['TeamName'][k] == teamB)):
            indexB = k
            break
    for s in range(len(stats_vec)):
        stat = stats_vec[s]
        r8_2017_data[i][s] = stats_data_2017[stat][indexA] - stats_data_2017[stat][indexB]
        
r8_2017_data = preprocessing.normalize(r8_2017_data, axis=0, norm='max')
r8_2017_dmatrix = xgb.DMatrix(r8_2017_data, label=r8_2017_labels,
                    feature_names=stats_vec)
r8_2017_pred = final_gb.predict(r8_2017_dmatrix)
#0 index is teamB win - 1 index is teamA win
print("\n\nElite 8 Predictions - 2017")
for i in range(len(r8_2017_pred)):
    teamA = r8_2017_teams[i][0]
    teamB = r8_2017_teams[i][1]
    if r8_2017_pred[i][1] > r8_2017_pred[i][0]: #team A win
        print("Winner:", teamA)
        print("Loser: ", teamB, '\n')
    else: #team B win
        print("Winner:", teamB)
        print("Loser: ", teamA, '\n')
# Out:
# Elite 8 Predictions - 2017
# Winner: Villanova
# Loser:  Duke
#
# Winner: Gonzaga
# Loser:  Arizona
#
# Winner: Kansas
# Loser:  Louisville
#
# Winner: North Carolina
# Loser:  Kentucky

# %%
r4_2017_teams = [["Villanova","Gonzaga"],
                 ["Kansas","North Carolina"]]

r4_2017_data = np.zeros((2,13))
r4_2017_labels = np.zeros((2,1))

for i in range(2):
    year = 2017
    teamA = r4_2017_teams[i][0]
    teamB = r4_2017_teams[i][1]
    for k in range(len(stats_data_2017)):
        if ((stats_data_2017['Season'][k] == year) and (stats_data_2017['TeamName'][k] == teamA)):
            indexA = k
            break
            
    for k in range(len(stats_data_2017)):
        if ((stats_data_2017['Season'][k] == year) and (stats_data_2017['TeamName'][k] == teamB)):
            indexB = k
            break
    for s in range(len(stats_vec)):
        stat = stats_vec[s]
        r4_2017_data[i][s] = stats_data_2017[stat][indexA] - stats_data_2017[stat][indexB]
        
r4_2017_data = preprocessing.normalize(r4_2017_data, axis=0, norm='max')
r4_2017_dmatrix = xgb.DMatrix(r4_2017_data, label=r4_2017_labels,
                    feature_names=stats_vec)
r4_2017_pred = final_gb.predict(r4_2017_dmatrix)
#0 index is teamB win - 1 index is teamA win
print("\n\nFinal 4 Predictions - 2017")
for i in range(len(r4_2017_pred)):
    teamA = r4_2017_teams[i][0]
    teamB = r4_2017_teams[i][1]
    if r4_2017_pred[i][1] > r4_2017_pred[i][0]: #team A win
        print("Winner:", teamA)
        print("Loser: ", teamB, '\n')
    else: #team B win
        print("Winner:", teamB)
        print("Loser: ", teamA, '\n')
# Out:
# Final 4 Predictions - 2017
# Winner: Villanova
# Loser:  Gonzaga
#
# Winner: Kansas
# Loser:  North Carolina

# %%
r2_2017_teams = [["Villanova","Kansas"]]

r2_2017_data = np.zeros((1,13))
r2_2017_labels = np.zeros((1,1))

for i in range(1):
    year = 2017
    teamA = r2_2017_teams[i][0]
    teamB = r2_2017_teams[i][1]
    for k in range(len(stats_data_2017)):
        if ((stats_data_2017['Season'][k] == year) and (stats_data_2017['TeamName'][k] == teamA)):
            indexA = k
            break
            
    for k in range(len(stats_data_2017)):
        if ((stats_data_2017['Season'][k] == year) and (stats_data_2017['TeamName'][k] == teamB)):
            indexB = k
            break
    for s in range(len(stats_vec)):
        stat = stats_vec[s]
        r2_2017_data[i][s] = stats_data_2017[stat][indexA] - stats_data_2017[stat][indexB]
        
r2_2017_data = preprocessing.normalize(r2_2017_data, axis=0, norm='max')
r2_2017_dmatrix = xgb.DMatrix(r2_2017_data, label=r2_2017_labels,
                    feature_names=stats_vec)
r2_2017_pred = final_gb.predict(r2_2017_dmatrix)
#0 index is teamB win - 1 index is teamA win
print("\n\nNational Championship Prediction - 2017")
for i in range(len(r2_2017_pred)):
    teamA = r2_2017_teams[i][0]
    teamB = r2_2017_teams[i][1]
    if r2_2017_pred[i][1] > r2_2017_pred[i][0]: #team A win
        print("Winner:", teamA)
        print("Loser: ", teamB, '\n')
    else: #team B win
        print("Winner:", teamB)
        print("Loser: ", teamA, '\n')
# Out:
# National Championship Prediction - 2017
# Winner: Villanova
# Loser:  Kansas

# %%
# I wanted to also see how well the machine predicts closely seeded games
# Obviously it does will with 1v16 and 2v15 matchups, but how well would it do
# when a 1v3, or 2v3, or even 1v1 matchup arises?

even_matchup_mask = testing_data[:,4] >= -2

even_matchup_stats = testing_data[even_matchup_mask]
even_matchup_ypred = ypred[even_matchup_mask]
even_matchup_labels = testing_labels[even_matchup_mask]

correct_list = np.zeros_like(even_matchup_labels)
for i in range(len(even_matchup_ypred)):
    if even_matchup_ypred[i][0] < even_matchup_ypred[i][1]:
        metric = 1 # team A predicted to win
    else:
        metric = 0
    correct_list[i][0] = metric
    #print("TeamA Win% {:.4}  SeedDiff {}".format(even_matchup_ypred[i][1]*100,even_matchup_stats[i][4]*-1))
    
print("% Correct: ", (correct_list.sum() / len(correct_list))*100)
